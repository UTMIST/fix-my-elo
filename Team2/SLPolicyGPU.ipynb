# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
from torch.utils.data import DataLoader, TensorDataset
from data_processing import generate_dataset_from_pgn, label_to_move_table, fen_to_board
import chess
# Out:
# g4f7n

# %%
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

dataset = generate_dataset_from_pgn("masaurus101-white.pgn")
train_to_test_ratio = 0.8

train_size = int(len(dataset) * train_to_test_ratio)
test_size = len(dataset) - train_size

# Split the dataset
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# Convert to tensors (simpler now since labels are already integers!)
X_train = torch.stack([board for board, label in train_data])  # (N, 8, 8, 12)
t_train = torch.tensor([label for board, label in train_data])  # (N,)

X_test = torch.stack([board for board, label in test_data])
t_test = torch.tensor([label for board, label in test_data])

# Create DataLoaders
batch_size = 32
train_dataset = TensorDataset(X_train, t_train)
test_dataset = TensorDataset(X_test, t_test)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 4
#       1 os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
#       3 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ----> 4 print(f"Using device : {torch.cuda.get_device_name(torch.cuda.current_device())}")
#       6 dataset = generate_dataset_from_pgn("masaurus101-white.pgn")
#       7 train_to_test_ratio = 0.8
#
# File /opt/anaconda3/envs/chess/lib/python3.11/site-packages/torch/cuda/__init__.py:971, in current_device()
#     969 def current_device() -> int:
#     970     r"""Return the index of a currently selected device."""
# --> 971     _lazy_init()
#     972     return torch._C._cuda_getDevice()
#
# File /opt/anaconda3/envs/chess/lib/python3.11/site-packages/torch/cuda/__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
#     306         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     307         "multiprocessing, you must use the 'spawn' start method"
#     308     )
#     309 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 310     raise AssertionError("Torch not compiled with CUDA enabled")
#     311 if _cudart is None:
#     312     raise AssertionError(
#     313         "libcudart functions unavailable. It looks like you have a broken build?"
#     314     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
class SLPolicyNetwork(nn.Module):
    def __init__(self, num_possible_moves=20480):
        super(SLPolicyNetwork, self).__init__()

        self.conv1 = nn.Conv2d(
            in_channels=12, out_channels=32, kernel_size=3, padding=1
        )
        self.conv2 = nn.Conv2d(
            in_channels=32, out_channels=64, kernel_size=3, padding=1
        )
        self.conv3 = nn.Conv2d(
            in_channels=64, out_channels=128, kernel_size=3, padding=1
        )

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, num_possible_moves)

    def forward(self, x):
        x = x.permute(0, 3, 1, 2)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = torch.flatten(x, start_dim=1)  # exclude batch dimension
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x


model = SLPolicyNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.1e-4)

# %%
def predict_move(model, board_tensor):
    """
    Takes a board tensor (8, 8, 12) and returns the predicted UCI move.
    """
    label_to_uci = label_to_move_table()
    model.eval()  # Set to evaluation mode
    

    with torch.no_grad():  # No gradients needed for inference
        # Add batch dimension: (8, 8, 12) -> (1, 8, 8, 12)
        board_batch = board_tensor.unsqueeze(0)

        # Get model output
        logits = model(board_batch)  # Shape: (1, 20480)
        probabilities = F.softmax(logits, dim=1)

        # Get the highest scoring move
        predicted_label = torch.argmax(probabilities, dim=1).item()

        # Convert to UCI
        predicted_uci = label_to_uci[predicted_label]

    return predicted_uci, probabilities[0][predicted_label]


def list_predicted_moves(model, board_tensor, num_moves):
    label_to_uci = label_to_move_table()

    model.eval()
    with torch.no_grad():
        board_batch = board_tensor.unsqueeze(0)
        logits = model(board_batch)  
        probabilities = F.softmax(logits, dim=1)
        score, moves = torch.topk(probabilities, num_moves)
        moves = [label_to_uci[int(move)] for move in moves[0]]
        

    return moves, score

# %%
epochs = 1

for epoch in range(epochs):
    for batch_idx, (data, target) in enumerate(train_dataloader):
        output = model(data)  # calculate predictions for this batch
        loss = criterion(output, target)  # calculate loss
        optimizer.zero_grad()  # reset gradient
        loss.backward()  # calculate gradient
        optimizer.step()  # update parameters

        if batch_idx % 100 == 0:
            print(f"Epoch {epoch+1}: Loss = {loss.item():.4f}")

    # doesn't really make sense to calculate validation accuracy as opening move has many possible moves

    # model.eval()
    # test_loss = 0
    # correct = 0

    # with torch.no_grad():
    #     for data, target in test_dataloader:
    #         # data, target = data.to(device), target.to(device)
    #         output = model(data)
    #         test_loss += criterion(output, target).item()
    #         correct += (output.argmax(1) == target).type(torch.float).sum().item()

    # print('epoch: {}, test loss: {:.6f}, test accuracy: {:.6f}'.format(
    #     epoch + 1,
    #     test_loss / len(test_dataloader),
    #     correct / len(test_dataloader.dataset)
    #     ))
# Out:
# Epoch 1: Loss = 9.9320
# Epoch 1: Loss = 9.9107
# Epoch 1: Loss = 9.6090
# Epoch 1: Loss = 7.7745
# Epoch 1: Loss = 6.9639
# Epoch 1: Loss = 7.1183
# Epoch 1: Loss = 6.9550
# Epoch 1: Loss = 6.5209
# Epoch 1: Loss = 7.5304
# Epoch 1: Loss = 6.6756

# %%
import chess
board = chess.Board()
board.push_uci('d2d4')
board_tensor = fen_to_board(board.fen())
print(predict_move(model, board_tensor))
print(list_predicted_moves(model, board_tensor, 5))

# label_to_move_table()

# MODEL PREDICTS ILLEGAL MOVES
# Out:
# ('b1c3', tensor(0.0180))
# (['b1c3', 'g8f6', 'd2d4', 'g1f3', 'e2e4'], tensor([[0.0180, 0.0175, 0.0161, 0.0156, 0.0151]]))
# {0: 'a1a1',
#  1: 'a1a1q',
#  2: 'a1a1r',
#  3: 'a1a1b',
#  4: 'a1a1n',
#  5: 'a1a2',
#  6: 'a1a2q',
#  7: 'a1a2r',
#  8: 'a1a2b',
#  9: 'a1a2n',
#  10: 'a1a3',
#  11: 'a1a3q',
#  12: 'a1a3r',
#  13: 'a1a3b',
#  14: 'a1a3n',
#  15: 'a1a4',
#  16: 'a1a4q',
#  17: 'a1a4r',
#  18: 'a1a4b',
#  19: 'a1a4n',
#  20: 'a1a5',
#  21: 'a1a5q',
#  22: 'a1a5r',
#  23: 'a1a5b',
#  24: 'a1a5n',
#  25: 'a1a6',
#  26: 'a1a6q',
#  27: 'a1a6r',
#  28: 'a1a6b',
#  29: 'a1a6n',
#  30: 'a1a7',
#  31: 'a1a7q',
#  32: 'a1a7r',
#  33: 'a1a7b',
#  34: 'a1a7n',
#  35: 'a1a8',
#  36: 'a1a8q',
#  37: 'a1a8r',
#  38: 'a1a8b',
#  39: 'a1a8n',
#  40: 'a1b1',
#  41: 'a1b1q',
#  42: 'a1b1r',
#  43: 'a1b1b',
#  44: 'a1b1n',
#  45: 'a1b2',
#  46: 'a1b2q',
#  47: 'a1b2r',
#  48: 'a1b2b',
#  49: 'a1b2n',
#  50: 'a1b3',
#  51: 'a1b3q',
#  52: 'a1b3r',
#  53: 'a1b3b',
#  54: 'a1b3n',
#  55: 'a1b4',
#  56: 'a1b4q',
#  57: 'a1b4r',
#  58: 'a1b4b',
#  59: 'a1b4n',
#  60: 'a1b5',
#  61: 'a1b5q',
#  62: 'a1b5r',
#  63: 'a1b5b',
#  64: 'a1b5n',
#  65: 'a1b6',
#  66: 'a1b6q',
#  67: 'a1b6r',
#  68: 'a1b6b',
#  69: 'a1b6n',
#  70: 'a1b7',
#  71: 'a1b7q',
#  72: 'a1b7r',
#  73: 'a1b7b',
#  74: 'a1b7n',
#  75: 'a1b8',
#  76: 'a1b8q',
#  77: 'a1b8r',
#  78: 'a1b8b',
#  79: 'a1b8n',
#  80: 'a1c1',
#  81: 'a1c1q',
#  82: 'a1c1r',
#  83: 'a1c1b',
#  84: 'a1c1n',
#  85: 'a1c2',
#  86: 'a1c2q',
#  87: 'a1c2r',
#  88: 'a1c2b',
#  89: 'a1c2n',
#  90: 'a1c3',
#  91: 'a1c3q',
#  92: 'a1c3r',
#  93: 'a1c3b',
#  94: 'a1c3n',
#  95: 'a1c4',
#  96: 'a1c4q',
#  97: 'a1c4r',
#  98: 'a1c4b',
#  99: 'a1c4n',
#  100: 'a1c5',
#  101: 'a1c5q',
#  102: 'a1c5r',
#  103: 'a1c5b',
#  104: 'a1c5n',
#  105: 'a1c6',
#  106: 'a1c6q',
#  107: 'a1c6r',
#  108: 'a1c6b',
#  109: 'a1c6n',
#  110: 'a1c7',
#  111: 'a1c7q',
#  112: 'a1c7r',
#  113: 'a1c7b',
#  114: 'a1c7n',
#  115: 'a1c8',
#  116: 'a1c8q',
#  117: 'a1c8r',
#  118: 'a1c8b',
#  119: 'a1c8n',
#  120: 'a1d1',
#  121: 'a1d1q',
#  122: 'a1d1r',
#  123: 'a1d1b',
#  124: 'a1d1n',
#  125: 'a1d2',
#  126: 'a1d2q',
#  127: 'a1d2r',
#  128: 'a1d2b',
#  129: 'a1d2n',
#  130: 'a1d3',
#  131: 'a1d3q',
#  132: 'a1d3r',
#  133: 'a1d3b',
#  134: 'a1d3n',
#  135: 'a1d4',
#  136: 'a1d4q',
#  137: 'a1d4r',
#  138: 'a1d4b',
#  139: 'a1d4n',
#  140: 'a1d5',
#  141: 'a1d5q',
#  142: 'a1d5r',
#  143: 'a1d5b',
#  144: 'a1d5n',
#  145: 'a1d6',
#  146: 'a1d6q',
#  147: 'a1d6r',
#  148: 'a1d6b',
#  149: 'a1d6n',
#  150: 'a1d7',
#  151: 'a1d7q',
#  152: 'a1d7r',
#  153: 'a1d7b',
#  154: 'a1d7n',
#  155: 'a1d8',
#  156: 'a1d8q',
#  157: 'a1d8r',
#  158: 'a1d8b',
#  159: 'a1d8n',
#  160: 'a1e1',
#  161: 'a1e1q',
#  162: 'a1e1r',
#  163: 'a1e1b',
#  164: 'a1e1n',
#  165: 'a1e2',
#  166: 'a1e2q',
#  167: 'a1e2r',
#  168: 'a1e2b',
#  169: 'a1e2n',
#  170: 'a1e3',
#  171: 'a1e3q',
#  172: 'a1e3r',
#  173: 'a1e3b',
#  174: 'a1e3n',
#  175: 'a1e4',
#  176: 'a1e4q',
#  177: 'a1e4r',
#  178: 'a1e4b',
#  179: 'a1e4n',
#  180: 'a1e5',
#  181: 'a1e5q',
#  182: 'a1e5r',
#  183: 'a1e5b',
#  184: 'a1e5n',
#  185: 'a1e6',
#  186: 'a1e6q',
#  187: 'a1e6r',
#  188: 'a1e6b',
#  189: 'a1e6n',
#  190: 'a1e7',
#  191: 'a1e7q',
#  192: 'a1e7r',
#  193: 'a1e7b',
#  194: 'a1e7n',
#  195: 'a1e8',
#  196: 'a1e8q',
#  197: 'a1e8r',
#  198: 'a1e8b',
#  199: 'a1e8n',
#  200: 'a1f1',
#  201: 'a1f1q',
#  202: 'a1f1r',
#  203: 'a1f1b',
#  204: 'a1f1n',
#  205: 'a1f2',
#  206: 'a1f2q',
#  207: 'a1f2r',
#  208: 'a1f2b',
#  209: 'a1f2n',
#  210: 'a1f3',
#  211: 'a1f3q',
#  212: 'a1f3r',
#  213: 'a1f3b',
#  214: 'a1f3n',
#  215: 'a1f4',
#  216: 'a1f4q',
#  217: 'a1f4r',
#  218: 'a1f4b',
#  219: 'a1f4n',
#  220: 'a1f5',
#  221: 'a1f5q',
#  222: 'a1f5r',
#  223: 'a1f5b',
#  224: 'a1f5n',
#  225: 'a1f6',
#  226: 'a1f6q',
#  227: 'a1f6r',
#  228: 'a1f6b',
#  229: 'a1f6n',
#  230: 'a1f7',
#  231: 'a1f7q',
#  232: 'a1f7r',
#  233: 'a1f7b',
#  234: 'a1f7n',
#  235: 'a1f8',
#  236: 'a1f8q',
#  237: 'a1f8r',
#  238: 'a1f8b',
#  239: 'a1f8n',
#  240: 'a1g1',
#  241: 'a1g1q',
#  242: 'a1g1r',
#  243: 'a1g1b',
#  244: 'a1g1n',
#  245: 'a1g2',
#  246: 'a1g2q',
#  247: 'a1g2r',
#  248: 'a1g2b',
#  249: 'a1g2n',
#  250: 'a1g3',
#  251: 'a1g3q',
#  252: 'a1g3r',
#  253: 'a1g3b',
#  254: 'a1g3n',
#  255: 'a1g4',
#  256: 'a1g4q',
#  257: 'a1g4r',
#  258: 'a1g4b',
#  259: 'a1g4n',
#  260: 'a1g5',
#  261: 'a1g5q',
#  262: 'a1g5r',
#  263: 'a1g5b',
#  264: 'a1g5n',
#  265: 'a1g6',
#  266: 'a1g6q',
#  267: 'a1g6r',
#  268: 'a1g6b',
#  269: 'a1g6n',
#  270: 'a1g7',
#  271: 'a1g7q',
#  272: 'a1g7r',
#  273: 'a1g7b',
#  274: 'a1g7n',
#  275: 'a1g8',
#  276: 'a1g8q',
#  277: 'a1g8r',
#  278: 'a1g8b',
#  279: 'a1g8n',
#  280: 'a1h1',
#  281: 'a1h1q',
#  282: 'a1h1r',
#  283: 'a1h1b',
#  284: 'a1h1n',
#  285: 'a1h2',
#  286: 'a1h2q',
#  287: 'a1h2r',
#  288: 'a1h2b',
#  289: 'a1h2n',
#  290: 'a1h3',
#  291: 'a1h3q',
#  292: 'a1h3r',
#  293: 'a1h3b',
#  294: 'a1h3n',
#  295: 'a1h4',
#  296: 'a1h4q',
#  297: 'a1h4r',
#  298: 'a1h4b',
#  299: 'a1h4n',
#  300: 'a1h5',
#  301: 'a1h5q',
#  302: 'a1h5r',
#  303: 'a1h5b',
#  304: 'a1h5n',
#  305: 'a1h6',
#  306: 'a1h6q',
#  307: 'a1h6r',
#  308: 'a1h6b',
#  309: 'a1h6n',
#  310: 'a1h7',
#  311: 'a1h7q',
#  312: 'a1h7r',
#  313: 'a1h7b',
#  314: 'a1h7n',
#  315: 'a1h8',
#  316: 'a1h8q',
#  317: 'a1h8r',
#  318: 'a1h8b',
#  319: 'a1h8n',
#  320: 'a2a1',
#  321: 'a2a1q',
#  322: 'a2a1r',
#  323: 'a2a1b',
#  324: 'a2a1n',
#  325: 'a2a2',
#  326: 'a2a2q',
#  327: 'a2a2r',
#  328: 'a2a2b',
#  329: 'a2a2n',
#  330: 'a2a3',
#  331: 'a2a3q',
#  332: 'a2a3r',
#  333: 'a2a3b',
#  334: 'a2a3n',
#  335: 'a2a4',
#  336: 'a2a4q',
#  337: 'a2a4r',
#  338: 'a2a4b',
#  339: 'a2a4n',
#  340: 'a2a5',
#  341: 'a2a5q',
#  342: 'a2a5r',
#  343: 'a2a5b',
#  344: 'a2a5n',
#  345: 'a2a6',
#  346: 'a2a6q',
#  347: 'a2a6r',
#  348: 'a2a6b',
#  349: 'a2a6n',
#  350: 'a2a7',
#  351: 'a2a7q',
#  352: 'a2a7r',
#  353: 'a2a7b',
#  354: 'a2a7n',
#  355: 'a2a8',
#  356: 'a2a8q',
#  357: 'a2a8r',
#  358: 'a2a8b',
#  359: 'a2a8n',
#  360: 'a2b1',
#  361: 'a2b1q',
#  362: 'a2b1r',
#  363: 'a2b1b',
#  364: 'a2b1n',
#  365: 'a2b2',
#  366: 'a2b2q',
#  367: 'a2b2r',
#  368: 'a2b2b',
#  369: 'a2b2n',
#  370: 'a2b3',
#  371: 'a2b3q',
#  372: 'a2b3r',
#  373: 'a2b3b',
#  374: 'a2b3n',
#  375: 'a2b4',
#  376: 'a2b4q',
#  377: 'a2b4r',
#  378: 'a2b4b',
#  379: 'a2b4n',
#  380: 'a2b5',
#  381: 'a2b5q',
#  382: 'a2b5r',
#  383: 'a2b5b',
#  384: 'a2b5n',
#  385: 'a2b6',
#  386: 'a2b6q',
#  387: 'a2b6r',
#  388: 'a2b6b',
#  389: 'a2b6n',
#  390: 'a2b7',
#  391: 'a2b7q',
#  392: 'a2b7r',
#  393: 'a2b7b',
#  394: 'a2b7n',
#  395: 'a2b8',
#  396: 'a2b8q',
#  397: 'a2b8r',
#  398: 'a2b8b',
#  399: 'a2b8n',
#  400: 'a2c1',
#  401: 'a2c1q',
#  402: 'a2c1r',
#  403: 'a2c1b',
#  404: 'a2c1n',
#  405: 'a2c2',
#  406: 'a2c2q',
#  407: 'a2c2r',
#  408: 'a2c2b',
#  409: 'a2c2n',
#  410: 'a2c3',
#  411: 'a2c3q',
#  412: 'a2c3r',
#  413: 'a2c3b',
#  414: 'a2c3n',
#  415: 'a2c4',
#  416: 'a2c4q',
#  417: 'a2c4r',
#  418: 'a2c4b',
#  419: 'a2c4n',
#  420: 'a2c5',
#  421: 'a2c5q',
#  422: 'a2c5r',
#  423: 'a2c5b',
#  424: 'a2c5n',
#  425: 'a2c6',
#  426: 'a2c6q',
#  427: 'a2c6r',
#  428: 'a2c6b',
#  429: 'a2c6n',
#  430: 'a2c7',
#  431: 'a2c7q',
#  432: 'a2c7r',
#  433: 'a2c7b',
#  434: 'a2c7n',
#  435: 'a2c8',
#  436: 'a2c8q',
#  437: 'a2c8r',
#  438: 'a2c8b',
#  439: 'a2c8n',
#  440: 'a2d1',
#  441: 'a2d1q',
#  442: 'a2d1r',
#  443: 'a2d1b',
#  444: 'a2d1n',
#  445: 'a2d2',
#  446: 'a2d2q',
#  447: 'a2d2r',
#  448: 'a2d2b',
#  449: 'a2d2n',
#  450: 'a2d3',
#  451: 'a2d3q',
#  452: 'a2d3r',
#  453: 'a2d3b',
#  454: 'a2d3n',
#  455: 'a2d4',
#  456: 'a2d4q',
#  457: 'a2d4r',
#  458: 'a2d4b',
#  459: 'a2d4n',
#  460: 'a2d5',
#  461: 'a2d5q',
#  462: 'a2d5r',
#  463: 'a2d5b',
#  464: 'a2d5n',
#  465: 'a2d6',
#  466: 'a2d6q',
#  467: 'a2d6r',
#  468: 'a2d6b',
#  469: 'a2d6n',
#  470: 'a2d7',
#  471: 'a2d7q',
#  472: 'a2d7r',
#  473: 'a2d7b',
#  474: 'a2d7n',
#  475: 'a2d8',
#  476: 'a2d8q',
#  477: 'a2d8r',
#  478: 'a2d8b',
#  479: 'a2d8n',
#  480: 'a2e1',
#  481: 'a2e1q',
#  482: 'a2e1r',
#  483: 'a2e1b',
#  484: 'a2e1n',
#  485: 'a2e2',
#  486: 'a2e2q',
#  487: 'a2e2r',
#  488: 'a2e2b',
#  489: 'a2e2n',
#  490: 'a2e3',
#  491: 'a2e3q',
#  492: 'a2e3r',
#  493: 'a2e3b',
#  494: 'a2e3n',
#  495: 'a2e4',
#  496: 'a2e4q',
#  497: 'a2e4r',
#  498: 'a2e4b',
#  499: 'a2e4n',
#  500: 'a2e5',
#  501: 'a2e5q',
#  502: 'a2e5r',
#  503: 'a2e5b',
#  504: 'a2e5n',
#  505: 'a2e6',
#  506: 'a2e6q',
#  507: 'a2e6r',
#  508: 'a2e6b',
#  509: 'a2e6n',
#  510: 'a2e7',
#  511: 'a2e7q',
#  512: 'a2e7r',
#  513: 'a2e7b',
#  514: 'a2e7n',
#  515: 'a2e8',
#  516: 'a2e8q',
#  517: 'a2e8r',
#  518: 'a2e8b',
#  519: 'a2e8n',
#  520: 'a2f1',
#  521: 'a2f1q',
#  522: 'a2f1r',
#  523: 'a2f1b',
#  524: 'a2f1n',
#  525: 'a2f2',
#  526: 'a2f2q',
#  527: 'a2f2r',
#  528: 'a2f2b',
#  529: 'a2f2n',
#  530: 'a2f3',
#  531: 'a2f3q',
#  532: 'a2f3r',
#  533: 'a2f3b',
#  534: 'a2f3n',
#  535: 'a2f4',
#  536: 'a2f4q',
#  537: 'a2f4r',
#  538: 'a2f4b',
#  539: 'a2f4n',
#  540: 'a2f5',
#  541: 'a2f5q',
#  542: 'a2f5r',
#  543: 'a2f5b',
#  544: 'a2f5n',
#  545: 'a2f6',
#  546: 'a2f6q',
#  547: 'a2f6r',
#  548: 'a2f6b',
#  549: 'a2f6n',
#  550: 'a2f7',
#  551: 'a2f7q',
#  552: 'a2f7r',
#  553: 'a2f7b',
#  554: 'a2f7n',
#  555: 'a2f8',
#  556: 'a2f8q',
#  557: 'a2f8r',
#  558: 'a2f8b',
#  559: 'a2f8n',
#  560: 'a2g1',
#  561: 'a2g1q',
#  562: 'a2g1r',
#  563: 'a2g1b',
#  564: 'a2g1n',
#  565: 'a2g2',
#  566: 'a2g2q',
#  567: 'a2g2r',
#  568: 'a2g2b',
#  569: 'a2g2n',
#  570: 'a2g3',
#  571: 'a2g3q',
#  572: 'a2g3r',
#  573: 'a2g3b',
#  574: 'a2g3n',
#  575: 'a2g4',
#  576: 'a2g4q',
#  577: 'a2g4r',
#  578: 'a2g4b',
#  579: 'a2g4n',
#  580: 'a2g5',
#  581: 'a2g5q',
#  582: 'a2g5r',
#  583: 'a2g5b',
#  584: 'a2g5n',
#  585: 'a2g6',
#  586: 'a2g6q',
#  587: 'a2g6r',
#  588: 'a2g6b',
#  589: 'a2g6n',
#  590: 'a2g7',
#  591: 'a2g7q',
#  592: 'a2g7r',
#  593: 'a2g7b',
#  594: 'a2g7n',
#  595: 'a2g8',
#  596: 'a2g8q',
#  597: 'a2g8r',
#  598: 'a2g8b',
#  599: 'a2g8n',
#  600: 'a2h1',
#  601: 'a2h1q',
#  602: 'a2h1r',
#  603: 'a2h1b',
#  604: 'a2h1n',
#  605: 'a2h2',
#  606: 'a2h2q',
#  607: 'a2h2r',
#  608: 'a2h2b',
#  609: 'a2h2n',
#  610: 'a2h3',
#  611: 'a2h3q',
#  612: 'a2h3r',
#  613: 'a2h3b',
#  614: 'a2h3n',
#  615: 'a2h4',
#  616: 'a2h4q',
#  617: 'a2h4r',
#  618: 'a2h4b',
#  619: 'a2h4n',
#  620: 'a2h5',
#  621: 'a2h5q',
#  622: 'a2h5r',
#  623: 'a2h5b',
#  624: 'a2h5n',
#  625: 'a2h6',
#  626: 'a2h6q',
#  627: 'a2h6r',
#  628: 'a2h6b',
#  629: 'a2h6n',
#  630: 'a2h7',
#  631: 'a2h7q',
#  632: 'a2h7r',
#  633: 'a2h7b',
#  634: 'a2h7n',
#  635: 'a2h8',
#  636: 'a2h8q',
#  637: 'a2h8r',
#  638: 'a2h8b',
#  639: 'a2h8n',
#  640: 'a3a1',
#  641: 'a3a1q',
#  642: 'a3a1r',
#  643: 'a3a1b',
#  644: 'a3a1n',
#  645: 'a3a2',
#  646: 'a3a2q',
#  647: 'a3a2r',
#  648: 'a3a2b',
#  649: 'a3a2n',
#  650: 'a3a3',
#  651: 'a3a3q',
#  652: 'a3a3r',
#  653: 'a3a3b',
#  654: 'a3a3n',
#  655: 'a3a4',
#  656: 'a3a4q',
#  657: 'a3a4r',
#  658: 'a3a4b',
#  659: 'a3a4n',
#  660: 'a3a5',
#  661: 'a3a5q',
#  662: 'a3a5r',
#  663: 'a3a5b',
#  664: 'a3a5n',
#  665: 'a3a6',
#  666: 'a3a6q',
#  667: 'a3a6r',
#  668: 'a3a6b',
#  669: 'a3a6n',
#  670: 'a3a7',
#  671: 'a3a7q',
#  672: 'a3a7r',
#  673: 'a3a7b',
#  674: 'a3a7n',
#  675: 'a3a8',
#  676: 'a3a8q',
#  677: 'a3a8r',
#  678: 'a3a8b',
#  679: 'a3a8n',
#  680: 'a3b1',
#  681: 'a3b1q',
#  682: 'a3b1r',
#  683: 'a3b1b',
#  684: 'a3b1n',
#  685: 'a3b2',
#  686: 'a3b2q',
#  687: 'a3b2r',
#  688: 'a3b2b',
#  689: 'a3b2n',
#  690: 'a3b3',
#  691: 'a3b3q',
#  692: 'a3b3r',
#  693: 'a3b3b',
#  694: 'a3b3n',
#  695: 'a3b4',
#  696: 'a3b4q',
#  697: 'a3b4r',
#  698: 'a3b4b',
#  699: 'a3b4n',
#  700: 'a3b5',
#  701: 'a3b5q',
#  702: 'a3b5r',
#  703: 'a3b5b',
#  704: 'a3b5n',
#  705: 'a3b6',
#  706: 'a3b6q',
#  707: 'a3b6r',
#  708: 'a3b6b',
#  709: 'a3b6n',
#  710: 'a3b7',
#  711: 'a3b7q',
#  712: 'a3b7r',
#  713: 'a3b7b',
#  714: 'a3b7n',
#  715: 'a3b8',
#  716: 'a3b8q',
#  717: 'a3b8r',
#  718: 'a3b8b',
#  719: 'a3b8n',
#  720: 'a3c1',
#  721: 'a3c1q',
#  722: 'a3c1r',
#  723: 'a3c1b',
#  724: 'a3c1n',
#  725: 'a3c2',
#  726: 'a3c2q',
#  727: 'a3c2r',
#  728: 'a3c2b',
#  729: 'a3c2n',
#  730: 'a3c3',
#  731: 'a3c3q',
#  732: 'a3c3r',
#  733: 'a3c3b',
#  734: 'a3c3n',
#  735: 'a3c4',
#  736: 'a3c4q',
#  737: 'a3c4r',
#  738: 'a3c4b',
#  739: 'a3c4n',
#  740: 'a3c5',
#  741: 'a3c5q',
#  742: 'a3c5r',
#  743: 'a3c5b',
#  744: 'a3c5n',
#  745: 'a3c6',
#  746: 'a3c6q',
#  747: 'a3c6r',
#  748: 'a3c6b',
#  749: 'a3c6n',
#  750: 'a3c7',
#  751: 'a3c7q',
#  752: 'a3c7r',
#  753: 'a3c7b',
#  754: 'a3c7n',
#  755: 'a3c8',
#  756: 'a3c8q',
#  757: 'a3c8r',
#  758: 'a3c8b',
#  759: 'a3c8n',
#  760: 'a3d1',
#  761: 'a3d1q',
#  762: 'a3d1r',
#  763: 'a3d1b',
#  764: 'a3d1n',
#  765: 'a3d2',
#  766: 'a3d2q',
#  767: 'a3d2r',
#  768: 'a3d2b',
#  769: 'a3d2n',
#  770: 'a3d3',
#  771: 'a3d3q',
#  772: 'a3d3r',
#  773: 'a3d3b',
#  774: 'a3d3n',
#  775: 'a3d4',
#  776: 'a3d4q',
#  777: 'a3d4r',
#  778: 'a3d4b',
#  779: 'a3d4n',
#  780: 'a3d5',
#  781: 'a3d5q',
#  782: 'a3d5r',
#  783: 'a3d5b',
#  784: 'a3d5n',
#  785: 'a3d6',
#  786: 'a3d6q',
#  787: 'a3d6r',
#  788: 'a3d6b',
#  789: 'a3d6n',
#  790: 'a3d7',
#  791: 'a3d7q',
#  792: 'a3d7r',
#  793: 'a3d7b',
#  794: 'a3d7n',
#  795: 'a3d8',
#  796: 'a3d8q',
#  797: 'a3d8r',
#  798: 'a3d8b',
#  799: 'a3d8n',
#  800: 'a3e1',
#  801: 'a3e1q',
#  802: 'a3e1r',
#  803: 'a3e1b',
#  804: 'a3e1n',
#  805: 'a3e2',
#  806: 'a3e2q',
#  807: 'a3e2r',
#  808: 'a3e2b',
#  809: 'a3e2n',
#  810: 'a3e3',
#  811: 'a3e3q',
#  812: 'a3e3r',
#  813: 'a3e3b',
#  814: 'a3e3n',
#  815: 'a3e4',
#  816: 'a3e4q',
#  817: 'a3e4r',
#  818: 'a3e4b',
#  819: 'a3e4n',
#  820: 'a3e5',
#  821: 'a3e5q',
#  822: 'a3e5r',
#  823: 'a3e5b',
#  824: 'a3e5n',
#  825: 'a3e6',
#  826: 'a3e6q',
#  827: 'a3e6r',
#  828: 'a3e6b',
#  829: 'a3e6n',
#  830: 'a3e7',
#  831: 'a3e7q',
#  832: 'a3e7r',
#  833: 'a3e7b',
#  834: 'a3e7n',
#  835: 'a3e8',
#  836: 'a3e8q',
#  837: 'a3e8r',
#  838: 'a3e8b',
#  839: 'a3e8n',
#  840: 'a3f1',
#  841: 'a3f1q',
#  842: 'a3f1r',
#  843: 'a3f1b',
#  844: 'a3f1n',
#  845: 'a3f2',
#  846: 'a3f2q',
#  847: 'a3f2r',
#  848: 'a3f2b',
#  849: 'a3f2n',
#  850: 'a3f3',
#  851: 'a3f3q',
#  852: 'a3f3r',
#  853: 'a3f3b',
#  854: 'a3f3n',
#  855: 'a3f4',
#  856: 'a3f4q',
#  857: 'a3f4r',
#  858: 'a3f4b',
#  859: 'a3f4n',
#  860: 'a3f5',
#  861: 'a3f5q',
#  862: 'a3f5r',
#  863: 'a3f5b',
#  864: 'a3f5n',
#  865: 'a3f6',
#  866: 'a3f6q',
#  867: 'a3f6r',
#  868: 'a3f6b',
#  869: 'a3f6n',
#  870: 'a3f7',
#  871: 'a3f7q',
#  872: 'a3f7r',
#  873: 'a3f7b',
#  874: 'a3f7n',
#  875: 'a3f8',
#  876: 'a3f8q',
#  877: 'a3f8r',
#  878: 'a3f8b',
#  879: 'a3f8n',
#  880: 'a3g1',
#  881: 'a3g1q',
#  882: 'a3g1r',
#  883: 'a3g1b',
#  884: 'a3g1n',
#  885: 'a3g2',
#  886: 'a3g2q',
#  887: 'a3g2r',
#  888: 'a3g2b',
#  889: 'a3g2n',
#  890: 'a3g3',
#  891: 'a3g3q',
#  892: 'a3g3r',
#  893: 'a3g3b',
#  894: 'a3g3n',
#  895: 'a3g4',
#  896: 'a3g4q',
#  897: 'a3g4r',
#  898: 'a3g4b',
#  899: 'a3g4n',
#  900: 'a3g5',
#  901: 'a3g5q',
#  902: 'a3g5r',
#  903: 'a3g5b',
#  904: 'a3g5n',
#  905: 'a3g6',
#  906: 'a3g6q',
#  907: 'a3g6r',
#  908: 'a3g6b',
#  909: 'a3g6n',
#  910: 'a3g7',
#  911: 'a3g7q',
#  912: 'a3g7r',
#  913: 'a3g7b',
#  914: 'a3g7n',
#  915: 'a3g8',
#  916: 'a3g8q',
#  917: 'a3g8r',
#  918: 'a3g8b',
#  919: 'a3g8n',
#  920: 'a3h1',
#  921: 'a3h1q',
#  922: 'a3h1r',
#  923: 'a3h1b',
#  924: 'a3h1n',
#  925: 'a3h2',
#  926: 'a3h2q',
#  927: 'a3h2r',
#  928: 'a3h2b',
#  929: 'a3h2n',
#  930: 'a3h3',
#  931: 'a3h3q',
#  932: 'a3h3r',
#  933: 'a3h3b',
#  934: 'a3h3n',
#  935: 'a3h4',
#  936: 'a3h4q',
#  937: 'a3h4r',
#  938: 'a3h4b',
#  939: 'a3h4n',
#  940: 'a3h5',
#  941: 'a3h5q',
#  942: 'a3h5r',
#  943: 'a3h5b',
#  944: 'a3h5n',
#  945: 'a3h6',
#  946: 'a3h6q',
#  947: 'a3h6r',
#  948: 'a3h6b',
#  949: 'a3h6n',
#  950: 'a3h7',
#  951: 'a3h7q',
#  952: 'a3h7r',
#  953: 'a3h7b',
#  954: 'a3h7n',
#  955: 'a3h8',
#  956: 'a3h8q',
#  957: 'a3h8r',
#  958: 'a3h8b',
#  959: 'a3h8n',
#  960: 'a4a1',
#  961: 'a4a1q',
#  962: 'a4a1r',
#  963: 'a4a1b',
#  964: 'a4a1n',
#  965: 'a4a2',
#  966: 'a4a2q',
#  967: 'a4a2r',
#  968: 'a4a2b',
#  969: 'a4a2n',
#  970: 'a4a3',
#  971: 'a4a3q',
#  972: 'a4a3r',
#  973: 'a4a3b',
#  974: 'a4a3n',
#  975: 'a4a4',
#  976: 'a4a4q',
#  977: 'a4a4r',
#  978: 'a4a4b',
#  979: 'a4a4n',
#  980: 'a4a5',
#  981: 'a4a5q',
#  982: 'a4a5r',
#  983: 'a4a5b',
#  984: 'a4a5n',
#  985: 'a4a6',
#  986: 'a4a6q',
#  987: 'a4a6r',
#  988: 'a4a6b',
#  989: 'a4a6n',
#  990: 'a4a7',
#  991: 'a4a7q',
#  992: 'a4a7r',
#  993: 'a4a7b',
#  994: 'a4a7n',
#  995: 'a4a8',
#  996: 'a4a8q',
#  997: 'a4a8r',
#  998: 'a4a8b',
#  999: 'a4a8n',
#  ...}

# %%
board = chess.Board()

moves_played = []
while not board.is_game_over():
    board_tensor = fen_to_board(board.fen())
    moves, probs = list_predicted_moves(model, board_tensor, 20480)
    
    for move in moves:
        try:
            board.push_uci(move)
        except chess.IllegalMoveError:
            continue
        break

    moves_played.append(move)

    print(board)
    print(moves_played)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . N . . . . .
# P P P P P P P P
# R . B Q K B N R
# ['b1c3']
# r n b q k b . r
# p p p p p p p p
# . . . . . n . .
# . . . . . . . .
# . . . . . . . .
# . . N . . . . .
# P P P P P P P P
# R . B Q K B N R
# ['b1c3', 'g8f6']
# r n b q k b . r
# p p p p p p p p
# . . . . . n . .
# . . . . . . . .
# . . . P . . . .
# . . N . . . . .
# P P P . P P P P
# R . B Q K B N R
# ['b1c3', 'g8f6', 'd2d4']
# r . b q k b . r
# p p p p p p p p
# . . n . . n . .
# . . . . . . . .
# . . . P . . . .
# . . N . . . . .
# P P P . P P P P
# R . B Q K B N R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6']
# r . b q k b . r
# p p p p p p p p
# . . n . . n . .
# . . . . . . . .
# . . . P . . . .
# . . N . . N . .
# P P P . P P P P
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3']
# r . b q k b . r
# p p p . p p p p
# . . n . . n . .
# . . . p . . . .
# . . . P . . . .
# . . N . . N . .
# P P P . P P P P
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5']
# r . b q k b . r
# p p p . p p p p
# . . n . . n . .
# . . . p . . . .
# . . . P P . . .
# . . N . . N . .
# P P P . . P P P
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4']
# r . b q k b . r
# p p p . . p p p
# . . n . . n . .
# . . . p p . . .
# . . . P P . . .
# . . N . . N . .
# P P P . . P P P
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5']
# r . b q k b . r
# p p p . . p p p
# . . n . . n . .
# . . . p p . . .
# . . . P P . . .
# . . N . . N P .
# P P P . . P . P
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3']
# r . b q k b . r
# p p p . . p . p
# . . n . . n p .
# . . . p p . . .
# . . . P P . . .
# . . N . . N P .
# P P P . . P . P
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6']
# r . b q k b . r
# p p p . . p . p
# . . n . . n p .
# . . . p p . . .
# . . . P P . . .
# . . N . . N P P
# P P P . . P . .
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3']
# r . b q k b . r
# p p p . . p . p
# . . . . . n p .
# . . . p p . . .
# . . . n P . . .
# . . N . . N P P
# P P P . . P . .
# R . B Q K B . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4']
# r . b q k b . r
# p p p . . p . p
# . . . . . n p .
# . . . p p . . .
# . . . n P . . .
# . . N . . N P P
# P P P . . P B .
# R . B Q K . . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2']
# r . b q k b . r
# p p . . . p . p
# . . p . . n p .
# . . . p p . . .
# . . . n P . . .
# . . N . . N P P
# P P P . . P B .
# R . B Q K . . R
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6']
# r . b q k b . r
# p p . . . p . p
# . . p . . n p .
# . . . p p . . .
# . . . n P . . .
# . . N . . N P P
# P P P . . P B .
# R . B Q . R K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1']
# r . . q k b . r
# p p . . . p . p
# . . p . . n p .
# . . . p p . . .
# . . . n P . b .
# . . N . . N P P
# P P P . . P B .
# R . B Q . R K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4']
# r . . q k b . r
# p p . . . p . p
# . . p . . n p .
# . . . p N . . .
# . . . n P . b .
# . . N . . . P P
# P P P . . P B .
# R . B Q . R K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5']
# r . . q k b . r
# p p . . . p . .
# . . p . . n p p
# . . . p N . . .
# . . . n P . b .
# . . N . . . P P
# P P P . . P B .
# R . B Q . R K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6']
# r . . q k b . r
# p p . . . p . .
# . . p . . n p p
# . . . p N . . .
# . . . n P . b .
# . . N . . . P P
# P P P . . P B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1']
# r . . q k . . r
# p p . . . p b .
# . . p . . n p p
# . . . p N . . .
# . . . n P . b .
# . . N . . . P P
# P P P . . P B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7']
# r . . q k . . r
# p p . . . p b .
# . . p . . n p p
# . . . p N . . .
# . . . n P P b .
# . . N . . . P P
# P P P . . . B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4']
# r . . q . r k .
# p p . . . p b .
# . . p . . n p p
# . . . p N . . .
# . . . n P P b .
# . . N . . . P P
# P P P . . . B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8']
# r . . q . r k .
# p p . . . p b .
# . . p . . n p p
# . . . N N . . .
# . . . n P P b .
# . . . . . . P P
# P P P . . . B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5']
# r . . q . r k .
# p . . . . p b .
# . . p . . n p p
# . p . N N . . .
# . . . n P P b .
# . . . . . . P P
# P P P . . . B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5']
# r . . q . r k .
# p . . . . p b .
# . . p . . n p p
# . p . N N . . .
# . . P n P P b .
# . . . . . . P P
# P P . . . . B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4']
# r . . q . r k .
# p . . . . p b .
# . . p . . . p p
# . p . N N . . .
# . . P n n P b .
# . . . . . . P P
# P P . . . . B .
# R . B Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4']
# r . . q . r k .
# p . . . . p b .
# . . p . . . p p
# . p . N N . . .
# . . P n n P b .
# . . . . B . P P
# P P . . . . B .
# R . . Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3']
# r . . q . r k .
# p . . . . . b .
# . . p . . p p p
# . p . N N . . .
# . . P n n P b .
# . . . . B . P P
# P P . . . . B .
# R . . Q R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6']
# r . . q . r k .
# p . . . . . b .
# . . p . . p p p
# . p . N N . . .
# . . P n n P b .
# . . . . B . P P
# P P . Q . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2']
# r . . q . r k .
# . . . . . . b .
# p . p . . p p p
# . p . N N . . .
# . . P n n P b .
# . . . . B . P P
# P P . Q . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6']
# r . . q . r k .
# . . . . . . b .
# p . p . . p p p
# . p . N N . . .
# . . P Q n P b .
# . . . . B . P P
# P P . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4']
# r . . q r . k .
# . . . . . . b .
# p . p . . p p p
# . p . N N . . .
# . . P Q n P b .
# . . . . B . P P
# P P . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8']
# r . . q r . k .
# . . . . . . b .
# p . p . . p p p
# . p . N N . . .
# . . P Q n P b .
# P . . . B . P P
# . P . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3']
# r . . . r . k .
# . . . q . . b .
# p . p . . p p p
# . p . N N . . .
# . . P Q n P b .
# P . . . B . P P
# . P . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7']
# r . . . r . k .
# . . . q . . b .
# p . p . . p p p
# . p . N N . . .
# . P P Q n P b .
# P . . . B . P P
# . . . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4']
# r . . . r . k .
# . . . . . . b .
# p . p . . p p p
# . p . q N . . .
# . P P Q n P b .
# P . . . B . P P
# . . . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5']
# r . . . r . k .
# . . . . . . b .
# p . p . . p p p
# . p . P N . . .
# . P . Q n P b .
# P . . . B . P P
# . . . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5']
# . . . r r . k .
# . . . . . . b .
# p . p . . p p p
# . p . P N . . .
# . P . Q n P b .
# P . . . B . P P
# . . . . . . B .
# R . . . R . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8']
# . . . r r . k .
# . . . . . . b .
# p . p . . p p p
# . p . P N . . .
# . P . Q n P b .
# P . . . B . P P
# . . . . . . B .
# R . R . . . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1']
# . . . . r . k .
# . . . r . . b .
# p . p . . p p p
# . p . P N . . .
# . P . Q n P b .
# P . . . B . P P
# . . . . . . B .
# R . R . . . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7']
# . . . . r . k .
# . . . r . . b .
# p . p . . p p p
# . p . P N . . .
# . P . Q n P b .
# P . . . B B P P
# . . . . . . . .
# R . R . . . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3']
# . . . . r . k .
# . . . . . . b .
# p . p . . p p p
# . p . r N . . .
# . P . Q n P b .
# P . . . B B P P
# . . . . . . . .
# R . R . . . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5']
# . . . . r . k .
# . . . . . . b .
# p . p . . p p p
# . p . Q N . . .
# . P . . n P b .
# P . . . B B P P
# . . . . . . . .
# R . R . . . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5']
# . . . . r . k .
# . . . . . . b .
# p . . . . p p p
# . p . p N . . .
# . P . . n P b .
# P . . . B B P P
# . . . . . . . .
# R . R . . . K .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5']
# . . . . r . k .
# . . . . . . b .
# p . . . . p p p
# . p . p N . . .
# . P . . n P b .
# P . . . B B P P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2']
# . . . . r . k .
# . . . . . . b .
# p . . . . p p p
# . p . p N . . .
# . P . . n P . .
# P . . . B b P P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3']
# . . . . r . k .
# . . . . . . b .
# p . . . . p p p
# . p . p N . . .
# . P . . n P P .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4']
# . . . . r . k .
# . . . . . . b .
# p . . . . . p p
# . p . p p . . .
# . P . . n P P .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5']
# . . . . r . k .
# . . . . . . b .
# p . . . . . p p
# . p . p p P . .
# . P . . n . P .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5']
# . . . . . . k .
# . . . . r . b .
# p . . . . . p p
# . p . p p P . .
# . P . . n . P .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7']
# . . . . . . k .
# . . . . r . b .
# p . . . . . p p
# . p . p p P P .
# . P . . n . . .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5']
# . . . . . . k .
# . . . . . . b .
# p . . . r . p p
# . p . p p P P .
# . P . . n . . .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6']
# . . . . . . k .
# . . . . . . b .
# p . . . r . P p
# . p . p p . P .
# . P . . n . . .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6']
# . . . . . . k .
# . . . . . . b .
# p . . . r . P .
# . p . p p . P p
# . P . . n . . .
# P . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5']
# . . . . . . k .
# . . . . . . b .
# p . . . r . P .
# . p . p p . P p
# P P . . n . . .
# . . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4']
# . . . . . . k .
# . . . . . . . .
# p . . . r . P b
# . p . p p . P p
# P P . . n . . .
# . . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . r . P b
# P p . p p . P p
# . P . . n . . .
# . . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5']
# . . . . . . k .
# . . . . . . b .
# p . . . r . P .
# P p . p p . P p
# . P . . n . . .
# . . . . B b . P
# . . . . . . . K
# R . R . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7']
# . . . . . . k .
# . . . . . . b .
# p . . . r . P .
# P p . p p . P p
# . P . . n . . .
# . . . . B b . P
# . . . . . . . K
# R R . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1']
# . . . . . . k .
# . . . . . . . .
# p . . . r . P b
# P p . p p . P p
# . P . . n . . .
# . . . . B b . P
# . . . . . . . K
# R R . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . r . P b
# P p . p p . P p
# . P . B n . . .
# . . . . . b . P
# . . . . . . . K
# R R . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4']
# . . . . . . k .
# . . . . . . . .
# p . . . r . P b
# P p . p . . P p
# . P . p n . . .
# . . . . . b . P
# . . . . . . . K
# R R . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4']
# . . . . . . k .
# . . . . . . . .
# p . . . r . P b
# P p . p . . P p
# . P . p n . . .
# . . . . . b . P
# . R . . . . . K
# R . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . p r . P p
# . P . p n . . .
# . . . . . b . P
# . R . . . . . K
# R . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . p r . P p
# . P . p n . . .
# . R . . . b . P
# . . . . . . . K
# R . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . p r . P p
# . P . p n . . .
# . R . . . b . P
# . . . . . . . K
# R . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . p r . P p
# . P . p n . . .
# . R . . . b . P
# . . . . . . . K
# . . . R . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . p r . P p
# . P . p n . . .
# . R . . . b . P
# . . . . . . . K
# . . . R . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . p r . P p
# . P . p n . . .
# . R . . . b . P
# . . . R . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . p r . P p
# . P . p n . . .
# . R . . . b . P
# . . . R . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . p r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . p r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7']
# . . . . . . k .
# . . . . . . b .
# p . . . . . P .
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . . r . P p
# . P . R n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6']
# . . . . . . k .
# . . . . . . . .
# p . . . . . P b
# P p . R r . P p
# . P . . n . . .
# . R . . . b . P
# . . . . . . . K
# . . . . . . . .
# ['b1c3', 'g8f6', 'd2d4', 'b8c6', 'g1f3', 'd7d5', 'e2e4', 'e7e5', 'g2g3', 'g7g6', 'h2h3', 'c6d4', 'f1g2', 'c7c6', 'e1g1', 'c8g4', 'f3e5', 'h7h6', 'f1e1', 'f8g7', 'f2f4', 'e8g8', 'c3d5', 'b7b5', 'c2c4', 'f6e4', 'c1e3', 'f7f6', 'd1d2', 'a7a6', 'd2d4', 'f8e8', 'a2a3', 'd8d7', 'b2b4', 'd7d5', 'c4d5', 'a8d8', 'e1c1', 'd8d7', 'g2f3', 'd7d5', 'd4d5', 'c6d5', 'g1h2', 'g4f3', 'g3g4', 'f6e5', 'f4f5', 'e8e7', 'g4g5', 'e7e6', 'f5g6', 'h6h5', 'a3a4', 'g7h6', 'a4a5', 'h6g7', 'c1b1', 'g7h6', 'e3d4', 'e5d4', 'b1b2', 'e6e5', 'b2b3', 'h6g7', 'a1d1', 'g7h6', 'd1d2', 'h6g7', 'd2d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5', 'h6g7', 'd5d4', 'g7h6', 'd4d5']
