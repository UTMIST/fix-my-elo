# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
from torch.utils.data import DataLoader, TensorDataset
from data_processing import generate_dataset_from_pgn, label_to_move_table, fen_to_board
import chess
import random

# %%
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

dataset = generate_dataset_from_pgn("masaurus101-white.pgn")
train_to_test_ratio = 0.8

train_size = int(len(dataset) * train_to_test_ratio)
test_size = len(dataset) - train_size

# Split the dataset
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# Convert to tensors (simpler now since labels are already integers!)
X_train = torch.stack([board for board, label in train_data])  # (N, 8, 8, 12)
t_train = torch.tensor([label for board, label in train_data])  # (N,)

X_test = torch.stack([board for board, label in test_data])
t_test = torch.tensor([label for board, label in test_data])

# Create DataLoaders
batch_size = 32
train_dataset = TensorDataset(X_train, t_train)
test_dataset = TensorDataset(X_test, t_test)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class SLPolicyNetwork(nn.Module):
    def __init__(self, num_possible_moves=20480):
        super(SLPolicyNetwork, self).__init__()

        self.conv1 = nn.Conv2d(
            in_channels=12, out_channels=32, kernel_size=3, padding=1
        )
        self.conv2 = nn.Conv2d(
            in_channels=32, out_channels=64, kernel_size=3, padding=1
        )
        self.conv3 = nn.Conv2d(
            in_channels=64, out_channels=128, kernel_size=3, padding=1
        )

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, num_possible_moves)

    def forward(self, x):
        x = x.permute(0, 3, 1, 2)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = torch.flatten(x, start_dim=1)  # exclude batch dimension
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x


model = SLPolicyNetwork()
model.load_state_dict(torch.load("sl_policy_network_KC.pth", map_location=torch.device("cpu")))
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.1e-4)

# %%
def predict_move(model, board_tensor):
    """
    Takes a board tensor (8, 8, 12) and returns the predicted UCI move.
    """
    label_to_uci = label_to_move_table()
    model.eval()  # Set to evaluation mode
    

    with torch.no_grad():  # No gradients needed for inference
        # Add batch dimension: (8, 8, 12) -> (1, 8, 8, 12)
        board_batch = board_tensor.unsqueeze(0)

        # Get model output
        logits = model(board_batch)  # Shape: (1, 20480)
        probabilities = F.softmax(logits, dim=1)

        # Get the highest scoring move
        predicted_label = torch.argmax(probabilities, dim=1).item()

        # Convert to UCI
        predicted_uci = label_to_uci[predicted_label]

    return predicted_uci, probabilities[0][predicted_label]


def list_predicted_moves(model, board_tensor, num_moves):
    label_to_uci = label_to_move_table()

    model.eval()
    with torch.no_grad():
        board_batch = board_tensor.unsqueeze(0)
        logits = model(board_batch)  
        probabilities = F.softmax(logits, dim=1)
        score, moves = torch.topk(probabilities, num_moves)
        moves = [label_to_uci[int(move)] for move in moves[0]]
        

    return moves, score

# %%
# epochs = 1

# for epoch in range(epochs):
#     for batch_idx, (data, target) in enumerate(train_dataloader):
#         output = model(data)  # calculate predictions for this batch
#         loss = criterion(output, target)  # calculate loss
#         optimizer.zero_grad()  # reset gradient
#         loss.backward()  # calculate gradient
#         optimizer.step()  # update parameters

#         if batch_idx % 100 == 0:
#             print(f"Epoch {epoch+1}: Loss = {loss.item():.4f}")

    # doesn't really make sense to calculate validation accuracy as opening move has many possible moves

    # model.eval()
    # test_loss = 0
    # correct = 0

    # with torch.no_grad():
    #     for data, target in test_dataloader:
    #         # data, target = data.to(device), target.to(device)
    #         output = model(data)
    #         test_loss += criterion(output, target).item()
    #         correct += (output.argmax(1) == target).type(torch.float).sum().item()

    # print('epoch: {}, test loss: {:.6f}, test accuracy: {:.6f}'.format(
    #     epoch + 1,
    #     test_loss / len(test_dataloader),
    #     correct / len(test_dataloader.dataset)
    #     ))

# %%
# import chess
# board = chess.Board()
# board.push_uci('d2d4')
# board_tensor = fen_to_board(board.fen())
# print(predict_move(model, board_tensor))
# print(list_predicted_moves(model, board_tensor, 5))

# label_to_move_table()

# MODEL PREDICTS ILLEGAL MOVES

# %%
board = chess.Board()
moves_played = []
model_turn = 1

while not board.is_game_over():
    move = None
    if model_turn:
        print("model")

        board_tensor = fen_to_board(board.fen())
        moves, probs = list_predicted_moves(model, board_tensor, 20480)
        
        for move in moves:
            try:
                board.push_uci(move)
            except chess.IllegalMoveError:
                continue
            break
        model_turn = 0
    else:
        print("random")
        moves = board.legal_moves
        move_index = random.randint(0, moves.count()-1)
        moves = [move for move in moves]
        move = moves[move_index]
        board.push(move)
        model_turn = 1

    moves_played.append(move)
    print(board)
    print(moves_played)
# Out:
# model
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# ['e2e4']
# random
# r n b q k b n r
# p . p p p p p p
# . . . . . . . .
# . p . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# ['e2e4', Move.from_uci('b7b5')]
# model
# r n b q k b n r
# p . p p p p p p
# . . . . . . . .
# . p . . . . . .
# . . . P P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4']
# random
# r n b q k b n r
# p . p . p p p p
# . . . p . . . .
# . p . . . . . .
# . . . P P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6')]
# model
# r n b q k b n r
# p . p . p p p p
# . . . p . . . .
# . p . . . . . .
# . . . P P . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3']
# random
# r n b . k b n r
# p . p q p p p p
# . . . p . . . .
# . p . . . . . .
# . . . P P . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7')]
# model
# r n b . k b n r
# p . p q p p p p
# . . . p . . . .
# . p . . . . . .
# . . . P P . . .
# . . N B . . . .
# P P P . . P P P
# R . B Q K . N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3']
# random
# r . b . k b n r
# p . p q p p p p
# . . n p . . . .
# . p . . . . . .
# . . . P P . . .
# . . N B . . . .
# P P P . . P P P
# R . B Q K . N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6')]
# model
# r . b . k b n r
# p . p q p p p p
# . . n p . . . .
# . p . . . . . .
# . . . P P . . .
# P . N B . . . .
# . P P . . P P P
# R . B Q K . N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3']
# random
# r . . . k b n r
# p b p q p p p p
# . . n p . . . .
# . p . . . . . .
# . . . P P . . .
# P . N B . . . .
# . P P . . P P P
# R . B Q K . N R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7')]
# model
# r . . . k b n r
# p b p q p p p p
# . . n p . . . .
# . p . . . . . .
# . . . P P . . .
# P . N B . . . .
# . P P . N P P P
# R . B Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2']
# random
# . . r . k b n r
# p b p q p p p p
# . . n p . . . .
# . p . . . . . .
# . . . P P . . .
# P . N B . . . .
# . P P . N P P P
# R . B Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8')]
# model
# . . r . k b n r
# p b p q p p p p
# . . n p . . . .
# . p . . . . B .
# . . . P P . . .
# P . N B . . . .
# . P P . N P P P
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5']
# random
# . . . r k b n r
# p b p q p p p p
# . . n p . . . .
# . p . . . . B .
# . . . P P . . .
# P . N B . . . .
# . P P . N P P P
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8')]
# model
# . . . r k b n r
# p b p q p p p p
# . . n p . . . .
# . p . . . . B .
# . . . P P . . P
# P . N B . . . .
# . P P . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4']
# random
# . . . r k b n r
# p b p q p p . p
# . . n p . . p .
# . p . . . . B .
# . . . P P . . P
# P . N B . . . .
# . P P . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6')]
# model
# . . . r k b n r
# p b p q p p . p
# . . n p . . p .
# . p . . . . B P
# . . . P P . . .
# P . N B . . . .
# . P P . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5']
# random
# b . . r k b n r
# p . p q p p . p
# . . n p . . p .
# . p . . . . B P
# . . . P P . . .
# P . N B . . . .
# . P P . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8')]
# model
# b . . r k b n r
# p . p q p p . p
# . . n p . . p .
# . p . N . . B P
# . . . P P . . .
# P . . B . . . .
# . P P . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5']
# random
# b . . r k . n r
# p . p q p p . p
# . . n p . . p b
# . p . N . . B P
# . . . P P . . .
# P . . B . . . .
# . P P . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6')]
# model
# b . . r k . n r
# p . p q p p . p
# . . n p . . p b
# . p . N . . B P
# . . . P P . . .
# P . P B . . . .
# . P . . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3']
# random
# b . . r k . n r
# p . p q p p . p
# . . n p . . p .
# . p . N . . b P
# . . . P P . . .
# P . P B . . . .
# . P . . N P P .
# R . . Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5')]
# model
# b . . r k . n r
# p . p q p p . p
# . . n p . . p .
# . p . N . . b P
# . . . P P . . .
# P . P B . . . .
# . P . . N P P .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1']
# random
# b . . r k . n r
# p . p q p . . p
# . . n p . p p .
# . p . N . . b P
# . . . P P . . .
# P . P B . . . .
# . P . . N P P .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6')]
# model
# b . . r k . n r
# p . p q p . . p
# . . n p . p p .
# . p . N . . b P
# . . . P P P . .
# P . P B . . . .
# . P . . N . P .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4']
# random
# b . . r k . n r
# p . p q p . . p
# . . n p . . p .
# . p . N . p b P
# . . . P P P . .
# P . P B . . . .
# . P . . N . P .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5')]
# model
# b . . r k . n r
# p . p q p . . p
# . . n p . . p .
# . p . N P p b P
# . . . P . P . .
# P . P B . . . .
# . P . . N . P .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5']
# random
# b . . r k . n r
# p . p q p . . p
# . . . p . . p .
# n p . N P p b P
# . . . P . P . .
# P . P B . . . .
# . P . . N . P .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5')]
# model
# b . . r k . n r
# p . p q p . . p
# . . . p . . p .
# n p . N P p b P
# . . . P . P . .
# P . P B . . P .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3']
# random
# b . r . k . n r
# p . p q p . . p
# . . . p . . p .
# n p . N P p b P
# . . . P . P . .
# P . P B . . P .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8')]
# model
# b . r . k . n r
# p . p q p . . p
# . . . p . . p .
# n p . N P p b P
# . . . P . P P .
# P . P B . . . .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4']
# random
# b . r k . . n r
# p . p q p . . p
# . . . p . . p .
# n p . N P p b P
# . . . P . P P .
# P . P B . . . .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8')]
# model
# b . r k . . n r
# p . p q p . . p
# . . . P . . p .
# n p . N . p b P
# . . . P . P P .
# P . P B . . . .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6']
# random
# b . r k . . n r
# . . p q p . . p
# p . . P . . p .
# n p . N . p b P
# . . . P . P P .
# P . P B . . . .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6')]
# model
# b . r k . . n r
# . . p q p . . p
# p . . P . . p .
# n p . N . p P P
# . . . P . . P .
# P . P B . . . .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5']
# random
# b . r . k . n r
# . . p q p . . p
# p . . P . . p .
# n p . N . p P P
# . . . P . . P .
# P . P B . . . .
# . P . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8')]
# model
# b . r . k . n r
# . . p q p . . p
# p . . P . . p .
# n p . N . p P P
# . P . P . . P .
# P . P B . . . .
# . . . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4']
# random
# b . r . k . n r
# . . p . p . . p
# p . . P q . p .
# n p . N . p P P
# . P . P . . P .
# P . P B . . . .
# . . . . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6')]
# model
# b . r . k . n r
# . . p . p . . p
# p . . P q . p .
# n p . N . p P P
# . P . P . . P .
# P . P . . . . .
# . . B . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2']
# random
# b . . r k . n r
# . . p . p . . p
# p . . P q . p .
# n p . N . p P P
# . P . P . . P .
# P . P . . . . .
# . . B . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8')]
# model
# b . . r k . n r
# . . p . P . . p
# p . . . q . p .
# n p . N . p P P
# . P . P . . P .
# P . P . . . . .
# . . B . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7']
# random
# b . . r k . n r
# . . p . P q . p
# p . . . . . p .
# n p . N . p P P
# . P . P . . P .
# P . P . . . . .
# . . B . N . . .
# . . R Q K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7')]
# model
# b . . r k . n r
# . . p . P q . p
# p . . . . . p .
# n p . N . p P P
# . P . P . . P .
# P . P Q . . . .
# . . B . N . . .
# . . R . K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3']
# random
# . . . r k . n r
# . b p . P q . p
# p . . . . . p .
# n p . N . p P P
# . P . P . . P .
# P . P Q . . . .
# . . B . N . . .
# . . R . K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7')]
# model
# . . . r k . n r
# . b p . P q . p
# p . . . . . p .
# n p . N . p P P
# . P . P . . P .
# P . P Q . . . .
# . . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1']
# random
# . . . r k q n r
# . b p . P . . p
# p . . . . . p .
# n p . N . p P P
# . P . P . . P .
# P . P Q . . . .
# . . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8')]
# model
# . . . r k q n r
# . b p . P . . p
# p . . . . . p .
# n p . N . p P P
# . P Q P . . P .
# P . P . . . . .
# . . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4']
# random
# . . . . k q n r
# . b p . P . . p
# p . . . . . p .
# n p . r . p P P
# . P Q P . . P .
# P . P . . . . .
# . . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5')]
# model
# . . . . k q n r
# . b p . P . . p
# p . . . . . p .
# n p . r . p P P
# . P . P . . P .
# P . P Q . . . .
# . . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3']
# random
# . . . . k q n r
# . b p . P . . p
# p . . . . . p .
# n p . . . p P P
# . P . r . . P .
# P . P Q . . . .
# . . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4')]
# model
# . . . . k q n r
# . b p . P . . p
# p . . . . . p .
# n p . . . p P P
# . P . r . . P .
# P . P . . . . .
# . . B Q N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2']
# random
# . . . . k q n r
# . b p . P . . .
# p . . . . . p p
# n p . . . p P P
# . P . r . . P .
# P . P . . . . .
# . . B Q N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6')]
# model
# . . . . k q n r
# . b p . P . . .
# p . . . . . p p
# n p . . . P P P
# . P . r . . . .
# P . P . . . . .
# . . B Q N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5']
# random
# . . . . k q n r
# . . p . P . . .
# p . . . . . p p
# n p . b . P P P
# . P . r . . . .
# P . P . . . . .
# . . B Q N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5')]
# model
# . . . . k q n r
# . . p . P . . .
# p . . . . . P p
# n p . b . . P P
# . P . r . . . .
# P . P . . . . .
# . . B Q N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6']
# random
# . . . . k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . . P P
# . P . r . . . .
# P . P . . . . .
# b . B Q N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2')]
# model
# . . . . k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . . P P
# . P . r . Q . .
# P . P . . . . .
# b . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4']
# random
# . . . r k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . . P P
# . P . . . Q . .
# P . P . . . . .
# b . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8')]
# model
# . . . r k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . Q P P
# . P . . . . . .
# P . P . . . . .
# b . B . N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5']
# random
# . . . . k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . Q P P
# . P . . . . . .
# P . P . . . . .
# b . B r N . . .
# . . R . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2')]
# model
# . . . . k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . Q P P
# . P . . . . . .
# P . P . . . . .
# b . B r N . . .
# . R . . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1']
# random
# . . . . k q n r
# . . p . P . . .
# p . . r . . P p
# n p . . . Q P P
# . P . . . . . .
# P . P . . . . .
# b . B . N . . .
# . R . . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6')]
# model
# . . . . k q n r
# . . p . P . . .
# p . . r . . P p
# n p . . . Q P P
# . P . . . . . .
# P R P . . . . .
# b . B . N . . .
# . . . . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3']
# random
# . . . r k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . Q P P
# . P . . . . . .
# P R P . . . . .
# b . B . N . . .
# . . . . K . R .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8')]
# model
# . . . r k q n r
# . . p . P . . .
# p . . . . . P p
# n p . . . Q P P
# . P . . . . . .
# P R P . . . . .
# b . B . N . . .
# . . . . K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1']
# random
# . . . r k q n r
# . . p . P . . .
# p . . . . . P p
# . p . . . Q P P
# . P n . . . . .
# P R P . . . . .
# b . B . N . . .
# . . . . K . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4')]
# model
# . . . r k q n r
# . . p . P . . .
# p . . . . . P p
# . p . . . Q P P
# . P n . . . . .
# P R P . . . . .
# b . B . N K . .
# . . . . . . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4'), 'e1f2']
# random
# . . . r k . n r
# . . p . q . . .
# p . . . . . P p
# . p . . . Q P P
# . P n . . . . .
# P R P . . . . .
# b . B . N K . .
# . . . . . . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4'), 'e1f2', Move.from_uci('f8e7')]
# model
# . . . r k . n r
# . . p . q . . .
# p . . . . . P p
# . p . . . Q P P
# . P n . . N . .
# P R P . . . . .
# b . B . . K . .
# . . . . . . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4'), 'e1f2', Move.from_uci('f8e7'), 'e2f4']
# random
# . . . r k . n r
# . . p . q . . .
# . . . . . . P p
# p p . . . Q P P
# . P n . . N . .
# P R P . . . . .
# b . B . . K . .
# . . . . . . . R
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4'), 'e1f2', Move.from_uci('f8e7'), 'e2f4', Move.from_uci('a6a5')]
# model
# . . . r k . n r
# . . p . q . . .
# . . . . . . P p
# p p . . . Q P P
# . P n . . N . .
# P R P . . . . .
# b . B . . K . .
# . . . . . . R .
# ...
# random
# . Q . . . . . .
# . b . . k . . .
# . K . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4'), 'e1f2', Move.from_uci('f8e7'), 'e2f4', Move.from_uci('a6a5'), 'h1g1', Move.from_uci('e7b4'), 'b3b4', Move.from_uci('c4d2'), 'g1f1', Move.from_uci('d8d5'), 'a3a4', Move.from_uci('d2b3'), 'a4b5', Move.from_uci('d5d2'), 'f2g1', Move.from_uci('h6g5'), 'f4e2', Move.from_uci('c7c5'), 'h5h6', Move.from_uci('c5b4'), 'c3c4', Move.from_uci('e8d8'), 'e2f4', Move.from_uci('d2d5'), 'f1f3', Move.from_uci('d8e8'), 'f3g3', Move.from_uci('h8h7'), 'g3f3', Move.from_uci('g8e7'), 'c2b3', Move.from_uci('e7g6'), 'f5e5', Move.from_uci('d5e5'), 'f3g3', Move.from_uci('h7c7'), 'g3f3', Move.from_uci('g5g4'), 'f3g3', Move.from_uci('e5c5'), 'b5b6', Move.from_uci('c7e7'), 'f4e6', Move.from_uci('a5a4'), 'h6h7', Move.from_uci('a2b3'), 'e6d4', Move.from_uci('e7e2'), 'd4f3', Move.from_uci('e2f2'), 'f3g5', Move.from_uci('b3c2'), 'g5e4', Move.from_uci('f2f8'), 'e4f6', Move.from_uci('e8f7'), 'b6b7', Move.from_uci('a4a3'), 'g1f1', Move.from_uci('c5c7'), 'f6g4', Move.from_uci('c7c8'), 'g3d3', Move.from_uci('c8b8'), 'f1g2', Move.from_uci('g6e7'), 'g4f2', Move.from_uci('c2d3'), 'g2g3', Move.from_uci('f7e8'), 'g3g4', Move.from_uci('d3g6'), 'g4g3', Move.from_uci('f8h8'), 'f2e4', Move.from_uci('g6h7'), 'e4d6', Move.from_uci('e8d7'), 'g3f4', Move.from_uci('h7e4'), 'f4e3', Move.from_uci('d7c7'), 'e3f4', Move.from_uci('b8e8'), 'd6f7', Move.from_uci('e4c2'), 'f7h8', Move.from_uci('c2a4'), 'f4e4', Move.from_uci('b4b3'), 'e4f3', Move.from_uci('e8d8'), 'f3e4', Move.from_uci('c7b6'), 'e4e3', Move.from_uci('d8d1'), 'e3e2', Move.from_uci('d1c1'), 'e2d2', Move.from_uci('e7f5'), 'd2d3', Move.from_uci('a4d7'), 'c4c5', Move.from_uci('b6a7'), 'd3e4', Move.from_uci('f5h4'), 'c5c6', Move.from_uci('b3b2'), 'e4d5', Move.from_uci('a3a2'), 'd5e4', Move.from_uci('b2b1r'), 'c6c7', Move.from_uci('h4f5'), 'e4f3', Move.from_uci('d7c6'), 'f3e2', Move.from_uci('f5h6'), 'e2e3', Move.from_uci('b1b4'), 'e3f2', Move.from_uci('b4b2'), 'f2e3', Move.from_uci('c6b7'), 'e3d4', Move.from_uci('b2g2'), 'd4e5', Move.from_uci('c1c5'), 'e5f6', Move.from_uci('g2g7'), 'f6g7', Move.from_uci('h6g4'), 'g7g6', Move.from_uci('b7h1'), 'g6g7', Move.from_uci('g4e5'), 'g7g8', Move.from_uci('c5c2'), 'g8h7', Move.from_uci('e5d3'), 'h7g6', Move.from_uci('d3f4'), 'g6f7', Move.from_uci('a2a1r'), 'f7f6', Move.from_uci('c2b2'), 'f6g7', Move.from_uci('h1f3'), 'g7f7', Move.from_uci('f3b7'), 'f7f6', Move.from_uci('a1b1'), 'f6e7', Move.from_uci('f4e2'), 'e7d7', Move.from_uci('b7c6'), 'd7c8', Move.from_uci('c6b5'), 'c8d8', Move.from_uci('b1g1'), 'd8c8', Move.from_uci('b5c4'), 'c8d8', Move.from_uci('g1g8'), 'd8d7', Move.from_uci('b2b1'), 'd7d6', Move.from_uci('c4b3'), 'd6d7', Move.from_uci('b3c4'), 'd7d6', Move.from_uci('g8b8'), 'd6d7', Move.from_uci('b1b4'), 'd7c6', Move.from_uci('e2g3'), 'c6d6', Move.from_uci('b8d8'), 'd6c5', Move.from_uci('b4b7'), 'c5c6', Move.from_uci('g3e2'), 'c6c5', Move.from_uci('b7b2'), 'c5c6', Move.from_uci('d8h8'), 'c6d7', Move.from_uci('e2d4'), 'd7d6', Move.from_uci('b2g2'), 'd6d7', Move.from_uci('g2g7') ...
# model
# . . Q . . . . .
# . b . . k . . .
# . K . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4'), 'e1f2', Move.from_uci('f8e7'), 'e2f4', Move.from_uci('a6a5'), 'h1g1', Move.from_uci('e7b4'), 'b3b4', Move.from_uci('c4d2'), 'g1f1', Move.from_uci('d8d5'), 'a3a4', Move.from_uci('d2b3'), 'a4b5', Move.from_uci('d5d2'), 'f2g1', Move.from_uci('h6g5'), 'f4e2', Move.from_uci('c7c5'), 'h5h6', Move.from_uci('c5b4'), 'c3c4', Move.from_uci('e8d8'), 'e2f4', Move.from_uci('d2d5'), 'f1f3', Move.from_uci('d8e8'), 'f3g3', Move.from_uci('h8h7'), 'g3f3', Move.from_uci('g8e7'), 'c2b3', Move.from_uci('e7g6'), 'f5e5', Move.from_uci('d5e5'), 'f3g3', Move.from_uci('h7c7'), 'g3f3', Move.from_uci('g5g4'), 'f3g3', Move.from_uci('e5c5'), 'b5b6', Move.from_uci('c7e7'), 'f4e6', Move.from_uci('a5a4'), 'h6h7', Move.from_uci('a2b3'), 'e6d4', Move.from_uci('e7e2'), 'd4f3', Move.from_uci('e2f2'), 'f3g5', Move.from_uci('b3c2'), 'g5e4', Move.from_uci('f2f8'), 'e4f6', Move.from_uci('e8f7'), 'b6b7', Move.from_uci('a4a3'), 'g1f1', Move.from_uci('c5c7'), 'f6g4', Move.from_uci('c7c8'), 'g3d3', Move.from_uci('c8b8'), 'f1g2', Move.from_uci('g6e7'), 'g4f2', Move.from_uci('c2d3'), 'g2g3', Move.from_uci('f7e8'), 'g3g4', Move.from_uci('d3g6'), 'g4g3', Move.from_uci('f8h8'), 'f2e4', Move.from_uci('g6h7'), 'e4d6', Move.from_uci('e8d7'), 'g3f4', Move.from_uci('h7e4'), 'f4e3', Move.from_uci('d7c7'), 'e3f4', Move.from_uci('b8e8'), 'd6f7', Move.from_uci('e4c2'), 'f7h8', Move.from_uci('c2a4'), 'f4e4', Move.from_uci('b4b3'), 'e4f3', Move.from_uci('e8d8'), 'f3e4', Move.from_uci('c7b6'), 'e4e3', Move.from_uci('d8d1'), 'e3e2', Move.from_uci('d1c1'), 'e2d2', Move.from_uci('e7f5'), 'd2d3', Move.from_uci('a4d7'), 'c4c5', Move.from_uci('b6a7'), 'd3e4', Move.from_uci('f5h4'), 'c5c6', Move.from_uci('b3b2'), 'e4d5', Move.from_uci('a3a2'), 'd5e4', Move.from_uci('b2b1r'), 'c6c7', Move.from_uci('h4f5'), 'e4f3', Move.from_uci('d7c6'), 'f3e2', Move.from_uci('f5h6'), 'e2e3', Move.from_uci('b1b4'), 'e3f2', Move.from_uci('b4b2'), 'f2e3', Move.from_uci('c6b7'), 'e3d4', Move.from_uci('b2g2'), 'd4e5', Move.from_uci('c1c5'), 'e5f6', Move.from_uci('g2g7'), 'f6g7', Move.from_uci('h6g4'), 'g7g6', Move.from_uci('b7h1'), 'g6g7', Move.from_uci('g4e5'), 'g7g8', Move.from_uci('c5c2'), 'g8h7', Move.from_uci('e5d3'), 'h7g6', Move.from_uci('d3f4'), 'g6f7', Move.from_uci('a2a1r'), 'f7f6', Move.from_uci('c2b2'), 'f6g7', Move.from_uci('h1f3'), 'g7f7', Move.from_uci('f3b7'), 'f7f6', Move.from_uci('a1b1'), 'f6e7', Move.from_uci('f4e2'), 'e7d7', Move.from_uci('b7c6'), 'd7c8', Move.from_uci('c6b5'), 'c8d8', Move.from_uci('b1g1'), 'd8c8', Move.from_uci('b5c4'), 'c8d8', Move.from_uci('g1g8'), 'd8d7', Move.from_uci('b2b1'), 'd7d6', Move.from_uci('c4b3'), 'd6d7', Move.from_uci('b3c4'), 'd7d6', Move.from_uci('g8b8'), 'd6d7', Move.from_uci('b1b4'), 'd7c6', Move.from_uci('e2g3'), 'c6d6', Move.from_uci('b8d8'), 'd6c5', Move.from_uci('b4b7'), 'c5c6', Move.from_uci('g3e2'), 'c6c5', Move.from_uci('b7b2'), 'c5c6', Move.from_uci('d8h8'), 'c6d7', Move.from_uci('e2d4'), 'd7d6', Move.from_uci('b2g2'), 'd6d7', Move.from_uci('g2g7') ...
# random
# . . b . . . . .
# . . . . k . . .
# . K . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# ['e2e4', Move.from_uci('b7b5'), 'd2d4', Move.from_uci('d7d6'), 'b1c3', Move.from_uci('d8d7'), 'f1d3', Move.from_uci('b8c6'), 'a2a3', Move.from_uci('c8b7'), 'g1e2', Move.from_uci('a8c8'), 'c1g5', Move.from_uci('c8d8'), 'h2h4', Move.from_uci('g7g6'), 'h4h5', Move.from_uci('b7a8'), 'c3d5', Move.from_uci('f8h6'), 'c2c3', Move.from_uci('h6g5'), 'a1c1', Move.from_uci('f7f6'), 'f2f4', Move.from_uci('f6f5'), 'e4e5', Move.from_uci('c6a5'), 'g2g3', Move.from_uci('d8c8'), 'g3g4', Move.from_uci('e8d8'), 'e5d6', Move.from_uci('a7a6'), 'f4g5', Move.from_uci('d8e8'), 'b2b4', Move.from_uci('d7e6'), 'd3c2', Move.from_uci('c8d8'), 'd6e7', Move.from_uci('e6f7'), 'd1d3', Move.from_uci('a8b7'), 'h1g1', Move.from_uci('f7f8'), 'd3c4', Move.from_uci('d8d5'), 'c4d3', Move.from_uci('d5d4'), 'd3d2', Move.from_uci('h7h6'), 'g4f5', Move.from_uci('b7d5'), 'f5g6', Move.from_uci('d5a2'), 'd2f4', Move.from_uci('d4d8'), 'f4f5', Move.from_uci('d8d2'), 'c1b1', Move.from_uci('d2d6'), 'b1b3', Move.from_uci('d6d8'), 'g1h1', Move.from_uci('a5c4'), 'e1f2', Move.from_uci('f8e7'), 'e2f4', Move.from_uci('a6a5'), 'h1g1', Move.from_uci('e7b4'), 'b3b4', Move.from_uci('c4d2'), 'g1f1', Move.from_uci('d8d5'), 'a3a4', Move.from_uci('d2b3'), 'a4b5', Move.from_uci('d5d2'), 'f2g1', Move.from_uci('h6g5'), 'f4e2', Move.from_uci('c7c5'), 'h5h6', Move.from_uci('c5b4'), 'c3c4', Move.from_uci('e8d8'), 'e2f4', Move.from_uci('d2d5'), 'f1f3', Move.from_uci('d8e8'), 'f3g3', Move.from_uci('h8h7'), 'g3f3', Move.from_uci('g8e7'), 'c2b3', Move.from_uci('e7g6'), 'f5e5', Move.from_uci('d5e5'), 'f3g3', Move.from_uci('h7c7'), 'g3f3', Move.from_uci('g5g4'), 'f3g3', Move.from_uci('e5c5'), 'b5b6', Move.from_uci('c7e7'), 'f4e6', Move.from_uci('a5a4'), 'h6h7', Move.from_uci('a2b3'), 'e6d4', Move.from_uci('e7e2'), 'd4f3', Move.from_uci('e2f2'), 'f3g5', Move.from_uci('b3c2'), 'g5e4', Move.from_uci('f2f8'), 'e4f6', Move.from_uci('e8f7'), 'b6b7', Move.from_uci('a4a3'), 'g1f1', Move.from_uci('c5c7'), 'f6g4', Move.from_uci('c7c8'), 'g3d3', Move.from_uci('c8b8'), 'f1g2', Move.from_uci('g6e7'), 'g4f2', Move.from_uci('c2d3'), 'g2g3', Move.from_uci('f7e8'), 'g3g4', Move.from_uci('d3g6'), 'g4g3', Move.from_uci('f8h8'), 'f2e4', Move.from_uci('g6h7'), 'e4d6', Move.from_uci('e8d7'), 'g3f4', Move.from_uci('h7e4'), 'f4e3', Move.from_uci('d7c7'), 'e3f4', Move.from_uci('b8e8'), 'd6f7', Move.from_uci('e4c2'), 'f7h8', Move.from_uci('c2a4'), 'f4e4', Move.from_uci('b4b3'), 'e4f3', Move.from_uci('e8d8'), 'f3e4', Move.from_uci('c7b6'), 'e4e3', Move.from_uci('d8d1'), 'e3e2', Move.from_uci('d1c1'), 'e2d2', Move.from_uci('e7f5'), 'd2d3', Move.from_uci('a4d7'), 'c4c5', Move.from_uci('b6a7'), 'd3e4', Move.from_uci('f5h4'), 'c5c6', Move.from_uci('b3b2'), 'e4d5', Move.from_uci('a3a2'), 'd5e4', Move.from_uci('b2b1r'), 'c6c7', Move.from_uci('h4f5'), 'e4f3', Move.from_uci('d7c6'), 'f3e2', Move.from_uci('f5h6'), 'e2e3', Move.from_uci('b1b4'), 'e3f2', Move.from_uci('b4b2'), 'f2e3', Move.from_uci('c6b7'), 'e3d4', Move.from_uci('b2g2'), 'd4e5', Move.from_uci('c1c5'), 'e5f6', Move.from_uci('g2g7'), 'f6g7', Move.from_uci('h6g4'), 'g7g6', Move.from_uci('b7h1'), 'g6g7', Move.from_uci('g4e5'), 'g7g8', Move.from_uci('c5c2'), 'g8h7', Move.from_uci('e5d3'), 'h7g6', Move.from_uci('d3f4'), 'g6f7', Move.from_uci('a2a1r'), 'f7f6', Move.from_uci('c2b2'), 'f6g7', Move.from_uci('h1f3'), 'g7f7', Move.from_uci('f3b7'), 'f7f6', Move.from_uci('a1b1'), 'f6e7', Move.from_uci('f4e2'), 'e7d7', Move.from_uci('b7c6'), 'd7c8', Move.from_uci('c6b5'), 'c8d8', Move.from_uci('b1g1'), 'd8c8', Move.from_uci('b5c4'), 'c8d8', Move.from_uci('g1g8'), 'd8d7', Move.from_uci('b2b1'), 'd7d6', Move.from_uci('c4b3'), 'd6d7', Move.from_uci('b3c4'), 'd7d6', Move.from_uci('g8b8'), 'd6d7', Move.from_uci('b1b4'), 'd7c6', Move.from_uci('e2g3'), 'c6d6', Move.from_uci('b8d8'), 'd6c5', Move.from_uci('b4b7'), 'c5c6', Move.from_uci('g3e2'), 'c6c5', Move.from_uci('b7b2'), 'c5c6', Move.from_uci('d8h8'), 'c6d7', Move.from_uci('e2d4'), 'd7d6', Move.from_uci('b2g2'), 'd6d7', Move.from_uci('g2g7') ...

# %%
def export_game_from_board(board: chess.Board, file_name: str):
    game = chess.pgn.Game()
    game.headers["Event"] = "AI Self Play"
    game.headers["White"] = "Your Model"
    game.headers["Black"] = "Your Model"
    game.headers["Result"] = board.result()

    # add moves to the game node
    node = game
    for move in board.move_stack:
        node = node.add_variation(move)

    # save to PGN file
    with open(f"{file_name}.pgn", "w", encoding="utf-8") as pgn_file:
        print(game, file=pgn_file)
    pgn_file.close()
# Out:
# 20

# %%
export_game_from_board(board, "model_vs_random")
