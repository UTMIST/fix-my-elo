# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
import chess

from torch.utils.data import DataLoader, TensorDataset
from data_processing import generate_dataset_from_pgn, label_to_move_table, fen_to_board

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {torch.cuda.get_device_name(torch.cuda.current_device())}")

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Out:
# Using device: NVIDIA GeForce RTX 4070 Laptop GPU

# %%
dataset = generate_dataset_from_pgn("tal.pgn") # dataset is a list of all moves in a game (8,8,12)
train_to_test_ratio = 0.8

train_size = int(len(dataset) * train_to_test_ratio)
test_size = len(dataset) - train_size

# Split the dataset
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# Convert to tensors (simpler now since labels are already integers!)
X_train = torch.stack([board for board, label in train_data])  # (N, 8, 8, 12)
t_train = torch.tensor([label for board, label in train_data])  # (N,)

X_test = torch.stack([board for board, label in test_data])
t_test = torch.tensor([label for board, label in test_data])

# Create DataLoaders
batch_size = 64
train_dataset = TensorDataset(X_train, t_train) # pairs x and y
test_dataset = TensorDataset(X_test, t_test)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

label_to_uci = label_to_move_table()

# %%
class SLPolicyNetwork(nn.Module):
    def __init__(self, num_possible_moves=20480):
        super(SLPolicyNetwork, self).__init__()

        self.conv1 = nn.Conv2d(
            in_channels=12, out_channels=32, kernel_size=3, padding=1
        )
        self.conv2 = nn.Conv2d(
            in_channels=32, out_channels=64, kernel_size=3, padding=1
        )
        self.conv3 = nn.Conv2d(
            in_channels=64, out_channels=128, kernel_size=3, padding=1
        )

        self.fc1 = nn.Linear(128 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, num_possible_moves)

    def forward(self, x):
        x = x.permute(0, 3, 1, 2)
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = torch.flatten(x, start_dim=1)  # exclude batch dimension
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# %%
model = SLPolicyNetwork().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.1e-3)

epochs = 100

for epoch in range(epochs):
    total_loss = 0
    model.train()

    for x_batch, y_batch in train_dataloader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(x_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    avg_loss = total_loss / len(train_dataloader)
    print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")

torch.save(model.state_dict(), "sl_policy_network.pth")
# Out:
# Epoch 1/100, Loss: 6.3119
# Epoch 2/100, Loss: 5.7362
# Epoch 3/100, Loss: 5.4182
# Epoch 4/100, Loss: 5.1370
# Epoch 5/100, Loss: 4.8850
# Epoch 6/100, Loss: 4.6486
# Epoch 7/100, Loss: 4.4293
# Epoch 8/100, Loss: 4.2182
# Epoch 9/100, Loss: 4.0222
# Epoch 10/100, Loss: 3.8417
# Epoch 11/100, Loss: 3.6753
# Epoch 12/100, Loss: 3.5228
# Epoch 13/100, Loss: 3.3836
# Epoch 14/100, Loss: 3.2545
# Epoch 15/100, Loss: 3.1338
# Epoch 16/100, Loss: 3.0203
# Epoch 17/100, Loss: 2.9127
# Epoch 18/100, Loss: 2.8090
# Epoch 19/100, Loss: 2.7109
# Epoch 20/100, Loss: 2.6154
# Epoch 21/100, Loss: 2.5242
# Epoch 22/100, Loss: 2.4348
# Epoch 23/100, Loss: 2.3473
# Epoch 24/100, Loss: 2.2617
# Epoch 25/100, Loss: 2.1773
# Epoch 26/100, Loss: 2.0984
# Epoch 27/100, Loss: 2.0176
# Epoch 28/100, Loss: 1.9386
# Epoch 29/100, Loss: 1.8633
# Epoch 30/100, Loss: 1.7885
# Epoch 31/100, Loss: 1.7136
# Epoch 32/100, Loss: 1.6423
# Epoch 33/100, Loss: 1.5719
# Epoch 34/100, Loss: 1.5037
# Epoch 35/100, Loss: 1.4377
# Epoch 36/100, Loss: 1.3691
# Epoch 37/100, Loss: 1.3056
# Epoch 38/100, Loss: 1.2446
# Epoch 39/100, Loss: 1.1842
# Epoch 40/100, Loss: 1.1262
# Epoch 41/100, Loss: 1.0695
# Epoch 42/100, Loss: 1.0187
# Epoch 43/100, Loss: 0.9641
# Epoch 44/100, Loss: 0.9143
# Epoch 45/100, Loss: 0.8658
# Epoch 46/100, Loss: 0.8247
# Epoch 47/100, Loss: 0.7789
# Epoch 48/100, Loss: 0.7413
# Epoch 49/100, Loss: 0.7032
# Epoch 50/100, Loss: 0.6697
# Epoch 51/100, Loss: 0.6343
# Epoch 52/100, Loss: 0.6093
# Epoch 53/100, Loss: 0.5798
# Epoch 54/100, Loss: 0.5546
# Epoch 55/100, Loss: 0.5298
# Epoch 56/100, Loss: 0.5095
# Epoch 57/100, Loss: 0.4909
# Epoch 58/100, Loss: 0.4792
# Epoch 59/100, Loss: 0.4564
# Epoch 60/100, Loss: 0.4447
# Epoch 61/100, Loss: 0.4359
# Epoch 62/100, Loss: 0.4194
# Epoch 63/100, Loss: 0.4106
# Epoch 64/100, Loss: 0.4004
# Epoch 65/100, Loss: 0.3937
# Epoch 66/100, Loss: 0.3831
# Epoch 67/100, Loss: 0.3789
# Epoch 68/100, Loss: 0.3695
# Epoch 69/100, Loss: 0.3663
# Epoch 70/100, Loss: 0.3599
# Epoch 71/100, Loss: 0.3541
# Epoch 72/100, Loss: 0.3528
# Epoch 73/100, Loss: 0.3443
# Epoch 74/100, Loss: 0.3430
# Epoch 75/100, Loss: 0.3372
# Epoch 76/100, Loss: 0.3341
# Epoch 77/100, Loss: 0.3295
# Epoch 78/100, Loss: 0.3283
# Epoch 79/100, Loss: 0.3224
# Epoch 80/100, Loss: 0.3188
# Epoch 81/100, Loss: 0.3183
# Epoch 82/100, Loss: 0.3157
# Epoch 83/100, Loss: 0.3104
# Epoch 84/100, Loss: 0.3121
# Epoch 85/100, Loss: 0.3057
# Epoch 86/100, Loss: 0.3042
# Epoch 87/100, Loss: 0.3040
# Epoch 88/100, Loss: 0.2999
# Epoch 89/100, Loss: 0.2972
# Epoch 90/100, Loss: 0.2988
# Epoch 91/100, Loss: 0.2974
# Epoch 92/100, Loss: 0.2927
# Epoch 93/100, Loss: 0.2917
# Epoch 94/100, Loss: 0.2878
# Epoch 95/100, Loss: 0.2864
# Epoch 96/100, Loss: 0.2862
# Epoch 97/100, Loss: 0.2816
# Epoch 98/100, Loss: 0.2820
# Epoch 99/100, Loss: 0.2830
# Epoch 100/100, Loss: 0.2799

# %%
def predict_move(model, board_tensor):
    """
    Takes a board tensor (8, 8, 12) and returns the predicted UCI move.
    """
    model.eval()  # Set to evaluation mode

    with torch.no_grad():  # No gradients needed for inference
        # Add batch dimension: (8, 8, 12) -> (1, 8, 8, 12)
        board_batch = board_tensor.unsqueeze(0).to(device)

        # Get model output
        outputs = model(board_batch)  # Shape: (1, 20480)

        # Get the highest scoring move
        predicted_label = torch.argmax(outputs, dim=1).item()

        # Convert to UCI
        predicted_uci = label_to_uci[predicted_label]

    return predicted_uci, predicted_label

def list_predicted_moves(model, board_tensor, num_moves):
    label_to_uci = label_to_move_table()

    model.eval()
    with torch.no_grad():
        board_batch = board_tensor.unsqueeze(0).to(device)
        logits = model(board_batch)  
        probabilities = F.softmax(logits, dim=1)
        score, moves = torch.topk(probabilities, num_moves)
        moves = [label_to_uci[int(move)] for move in moves[0]]
        

    return moves, score

# %%
board = chess.Board()
board.push_uci('d2d4')
board_tensor = fen_to_board(board.fen())
model = SLPolicyNetwork()
model.load_state_dict(torch.load("sl_policy_network.pth", map_location=device))
model.to(device)    
predict_move(model, board_tensor)
list_predicted_moves(model, board_tensor, 5)

# MODEL PREDICTS ILLEGAL MOVES

board = chess.Board()
moves_played = []
move_num = 0

while not board.is_game_over():
    board_tensor = fen_to_board(board.fen())
    
    # Get top predicted moves from the model
    moves, probs = list_predicted_moves(model, board_tensor, 10)
    
    # Filter predictions to only legal moves
    legal_moves = [move.uci() for move in board.legal_moves]
    move_played = None
    
    for move in moves:
        if move in legal_moves:
            board.push_uci(move)
            move_played = move
            break

    # If none of the top moves are legal, pick a random legal move
    if move_played is None:
        move_played = next(iter(board.legal_moves)).uci()
        board.push_uci(move_played)

    moves_played.append(move_played)
    move_num += 1
    
    # Print board and move number
    print(board)
    print(move_num)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# 1
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# 2
# r n b q k b n r
# p p . p p p p p
# . . . . . . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
# 3
# r n b q k b n r
# p p . . p p p p
# . . . p . . . .
# . . p . . . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
# 4
# r n b q k b n r
# p p . . p p p p
# . . . p . . . .
# . . p . . . . .
# . . . P P . . .
# . . . . . N . .
# P P P . . P P P
# R N B Q K B . R
# 5
# r n b q k b n r
# p p . . p p p p
# . . . p . . . .
# . . . . . . . .
# . . . p P . . .
# . . . . . N . .
# P P P . . P P P
# R N B Q K B . R
# 6
# r n b q k b n r
# p p . . p p p p
# . . . p . . . .
# . . . . . . . .
# . . . N P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B . R
# 7
# r n b q k b . r
# p p . . p p p p
# . . . p . n . .
# . . . . . . . .
# . . . N P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B . R
# 8
# r n b q k b . r
# p p . . p p p p
# . . . p . n . .
# . . . . . . . .
# . . . N P . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B . R
# 9
# r n b q k b . r
# . p . . p p p p
# p . . p . n . .
# . . . . . . . .
# . . . N P . . .
# . . N . . . . .
# P P P . . P P P
# R . B Q K B . R
# 10
# r n b q k b . r
# . p . . p p p p
# p . . p . n . .
# . . . . . . . .
# . . . N P P . .
# . . N . . . . .
# P P P . . . P P
# R . B Q K B . R
# 11
# r n b q k b . r
# . p . . . p p p
# p . . p p n . .
# . . . . . . . .
# . . . N P P . .
# . . N . . . . .
# P P P . . . P P
# R . B Q K B . R
# 12
# r n b q k b . r
# . p . . . p p p
# p . . p p n . .
# . . . . . . . .
# . . . N P P . .
# . . N . . . . .
# P P P . B . P P
# R . B Q K . . R
# 13
# r n b q k . . r
# . p . . b p p p
# p . . p p n . .
# . . . . . . . .
# . . . N P P . .
# . . N . . . . .
# P P P . B . P P
# R . B Q K . . R
# 14
# r n b q k . . r
# . p . . b p p p
# p . . p p n . .
# . . . . . . . .
# . . . N P P . .
# . . N . . . . .
# P P P . B . P P
# R . B Q . R K .
# 15
# r . b q k . . r
# . p . . b p p p
# p . n p p n . .
# . . . . . . . .
# . . . N P P . .
# . . N . . . . .
# P P P . B . P P
# R . B Q . R K .
# 16
# r . b q k . . r
# . p . . b p p p
# p . n p p n . .
# . . . . . . . .
# . . . N P P . .
# . . N . B . . .
# P P P . B . P P
# R . . Q . R K .
# 17
# r . b q . r k .
# . p . . b p p p
# p . n p p n . .
# . . . . . . . .
# . . . N P P . .
# . . N . B . . .
# P P P . B . P P
# R . . Q . R K .
# 18
# r . b q . r k .
# . p . . b p p p
# p . n p p n . .
# . . . . . . . .
# P . . N P P . .
# . . N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 19
# r . . q . r k .
# . p . b b p p p
# p . n p p n . .
# . . . . . . . .
# P . . N P P . .
# . . N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 20
# r . . q . r k .
# . p . b b p p p
# p . n p p n . .
# . . . . . . . .
# P . . . P P . .
# . N N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 21
# r . . q . r k .
# . p . b b p p p
# p . . p p n . .
# n . . . . . . .
# P . . . P P . .
# . N N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 22
# r . . q . r k .
# . p . b b p p p
# p . . p p n . .
# n . . . P . . .
# P . . . . P . .
# . N N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 23
# r . . q n r k .
# . p . b b p p p
# p . . p p . . .
# n . . . P . . .
# P . . . . P . .
# . N N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 24
# r . . q n r k .
# . p . b b p p p
# p . . p p . . .
# N . . . P . . .
# P . . . . P . .
# . . N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 25
# r . . . n r k .
# . p . b b p p p
# p . . p p . . .
# q . . . P . . .
# P . . . . P . .
# . . N . B . . .
# . P P . B . P P
# R . . Q . R K .
# 26
# r . . . n r k .
# . p . b b p p p
# p . . p p . . .
# q . . . P . . .
# P . . . N P . .
# . . . . B . . .
# . P P . B . P P
# R . . Q . R K .
# 27
# r . . . n r k .
# . p q b b p p p
# p . . p p . . .
# . . . . P . . .
# P . . . N P . .
# . . . . B . . .
# . P P . B . P P
# R . . Q . R K .
# 28
# r . . . n r k .
# . p q b b p p p
# p . . p p . . .
# . . . . P . . .
# P . . B N P . .
# . . . . . . . .
# . P P . B . P P
# R . . Q . R K .
# 29
# r . . . n r k .
# . p q . b p p p
# p . b p p . . .
# . . . . P . . .
# P . . B N P . .
# . . . . . . . .
# . P P . B . P P
# R . . Q . R K .
# 30
# r . . . n r k .
# . p q . b p p p
# p . b p p . . .
# . . . . P . . .
# P . . B N P . .
# . . . Q . . . .
# . P P . B . P P
# R . . . . R K .
# 31
# r . . . n r k .
# . p q . b p p p
# p . b . p . . .
# . . . . p . . .
# P . . B N P . .
# . . . Q . . . .
# . P P . B . P P
# R . . . . R K .
# 32
# r . . . n r k .
# . p q . b p p p
# p . b . p . . .
# . . . . P . . .
# P . . B N . . .
# . . . Q . . . .
# . P P . B . P P
# R . . . . R K .
# 33
# . . . r n r k .
# . p q . b p p p
# p . b . p . . .
# . . . . P . . .
# P . . B N . . .
# . . . Q . . . .
# . P P . B . P P
# R . . . . R K .
# 34
# . . . r n r k .
# . p q . b p p p
# p . b . p . . .
# . . . . P . . .
# P . . B N . . .
# . . . Q . . . .
# . P P . B . P P
# R . . . . R . K
# 35
# . . . r n r k .
# . p . q b p p p
# p . b . p . . .
# . . . . P . . .
# P . . B N . . .
# . . . Q . . . .
# . P P . B . P P
# R . . . . R . K
# 36
# . . . r n r k .
# . p . q b p p p
# p . b . p . . .
# . . . . P . . .
# P . . B N . . .
# . . . Q . . . .
# . P P . B . P P
# . . . R . R . K
# 37
# . . . r n r k .
# . p . q b . p p
# p . b . p . . .
# . . . . P p . .
# P . . B N . . .
# . . . Q . . . .
# . P P . B . P P
# . . . R . R . K
# 38
# . . . r n r k .
# . p . q b . p p
# p . b . p . . .
# . . . . P p . .
# P . . B . . . .
# . . N Q . . . .
# . P P . B . P P
# . . . R . R . K
# 39
# . . . r . r k .
# . p n q b . p p
# p . b . p . . .
# . . . . P p . .
# P . . B . . . .
# . . N Q . . . .
# . P P . B . P P
# . . . R . R . K
# 40
# . . . r . r k .
# . p n q b . p p
# p . b . p . . .
# . . . . P p . .
# P . . B . . . .
# . . N Q . B . .
# . P P . . . P P
# . . . R . R . K
# 41
# . . . r . r k .
# . p n q b . p p
# p . . . p . . .
# . . . . P p . .
# P . . B . . . .
# . . N Q . b . .
# . P P . . . P P
# . . . R . R . K
# 42
# . . . r . r k .
# . p n q b . p p
# p . . . p . . .
# . . . . P p . .
# P . . B . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R . K
# 43
# . . . r . r k .
# . p n . b . p p
# p . q . p . . .
# . . . . P p . .
# P . . B . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R . K
# 44
# . . . r . r k .
# . p n . b . p p
# p . q . p . . .
# . . . . P p . .
# P . . . . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R B K
# 45
# . . . r . r k .
# . p n . b . . p
# p . q . p . p .
# . . . . P p . .
# P . . . . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R B K
# 46
# . . . r . r k .
# . p n . b . . p
# p . q . p . p .
# P . . . P p . .
# . . . . . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R B K
# 47
# . . . r . r k .
# . p . . b . . p
# p . q . p . p .
# P . . n P p . .
# . . . . . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R B K
# 48
# . . . r . r k .
# . p . . b . . p
# p B q . p . p .
# P . . n P p . .
# . . . . . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R . K
# 49
# . . . . . r k .
# . p . r b . . p
# p B q . p . p .
# P . . n P p . .
# . . . . . . . .
# . . N . . Q . .
# . P P . . . P P
# . . . R . R . K
# 50
# . . . . . r k .
# . p . r b . . p
# p B q . p . p .
# P . . N P p . .
# . . . . . . . .
# . . . . . Q . .
# . P P . . . P P
# . . . R . R . K
# 51
# . . . . . r k .
# . p . . b . . p
# p B q . p . p .
# P . . r P p . .
# . . . . . . . .
# . . . . . Q . .
# . P P . . . P P
# . . . R . R . K
# 52
# . . . . . r k .
# . p . . b . . p
# p B q . p . p .
# P . . R P p . .
# . . . . . . . .
# . . . . . Q . .
# . P P . . . P P
# . . . . . R . K
# 53
# . . . . . r k .
# . p . . b . . p
# p B . . p . p .
# P . . q P p . .
# . . . . . . . .
# . . . . . Q . .
# . P P . . . P P
# . . . . . R . K
# 54
# . . . . . r k .
# . p . . b . . p
# p B . . p . p .
# P . . q P p . .
# . . . . . . . .
# . . . . . Q . .
# . P P . . . P P
# . . . R . . . K
# 55
# . . . . . r k .
# . p . . b . . p
# p B . . p . p .
# P . . . q p . .
# . . . . . . . .
# . . . . . Q . .
# . P P . . . P P
# . . . R . . . K
# 56
# . . . . . r k .
# . Q . . b . . p
# p B . . p . p .
# P . . . q p . .
# . . . . . . . .
# . . . . . . . .
# . P P . . . P P
# . . . R . . . K
# 57
# . . . . . r k .
# . Q . . b . . p
# p B . . p . p .
# P . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . P P . q . P P
# . . . R . . . K
# 58
# . . . . . r k .
# . . . Q b . . p
# p B . . p . p .
# P . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . P P . q . P P
# . . . R . . . K
# 59
# . . . . . r k .
# . . . Q . . . p
# p B . . p b p .
# P . . . . p . .
# . . . . . . . .
# . . . . . . . .
# . P P . q . P P
# . . . R . . . K
# 60
# . . . . . r k .
# . . . Q . . . p
# p B . . p b p .
# P . . . . p . .
# . P . . . . . .
# . . . . . . . .
# . . P . q . P P
# . . . R . . . K
# 61
# . . . . . r k .
# . . . Q . . . p
# p B . . p b p .
# P . . . . p . .
# . P . . . . . .
# . . . . . . . .
# . . q . . . P P
# . . . R . . . K
# 62
# . . . . . r k .
# . . . . . . . p
# p B . . Q b p .
# P . . . . p . .
# . P . . . . . .
# . . . . . . . .
# . . q . . . P P
# . . . R . . . K
# 63
# . . . . . r . k
# . . . . . . . p
# p B . . Q b p .
# P . . . . p . .
# . P . . . . . .
# . . . . . . . .
# . . q . . . P P
# . . . R . . . K
# 64
# . . . . . r . k
# . . . . . . . p
# p B . . Q b p .
# P . . . . p . .
# . P . . . . . .
# . . . . . . . .
# . . q . . . P P
# . . . . R . . K
# 65
# . . . . . r . k
# . . . . . . . p
# p B . . Q . p .
# P . . . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . . R . . K
# 66
# . . . . . r . k
# . . . . . . . p
# p . . . Q . p .
# P . B . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . . R . . K
# 67
# . . . r . . . k
# . . . . . . . p
# p . . . Q . p .
# P . B . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . . R . . K
# 68
# . . . r . . . k
# . . . . B . . p
# p . . . Q . p .
# P . . . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . . R . . K
# 69
# . . . . . . . k
# . . . . B . . p
# p . . . Q . p .
# P . . . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . r R . . K
# 70
# . . Q . . . . k
# . . . . B . . p
# p . . . . . p .
# P . . . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . r R . . K
# 71
# . . Q r . . . k
# . . . . B . . p
# p . . . . . p .
# P . . . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . . R . . K
# 72
# . Q . r . . . k
# . . . . B . . p
# p . . . . . p .
# P . . . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . . . P P
# . . . . R . . K
# 73
# . Q . r . . . k
# . . . . B . . p
# p . . . . . p .
# P . . . . p . .
# q P . . . . . .
# . . b . . . . .
# . . . . . . P P
# . . . . R . . K
# 74
# . Q . r . . . k
# . . . . B . . p
# p . . . . . p .
# P . . . . p . .
# q P . . . . . .
# . . b . . . . .
# . . . . R . P P
# . . . . . . . K
# 75
# . Q . . . . r k
# . . . . B . . p
# p . . . . . p .
# P . . . . p . .
# q P . . . . . .
# . . b . . . . .
# . . . . R . P P
# . . . . . . . K
# 76
# . . . . . . r k
# . Q . . B . . p
# p . . . . . p .
# P . . . . p . .
# q P . . . . . .
# . . b . . . . .
# . . . . R . P P
# . . . . . . . K
# 77
# . . . . . . r k
# . Q . . B . . p
# p . . . . . p .
# P . . . . p . .
# . P . . . . . .
# . . b . . . . .
# . . q . R . P P
# . . . . . . . K
# 78
# . . . . . . r k
# . Q . . B . . p
# p . . . . . p .
# P . . . . p . .
# . P . . . . . P
# . . b . . . . .
# . . q . R . P .
# . . . . . . . K
# 79
# . . . . . . r k
# . Q . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . b . . . . .
# . . q . R . P .
# . . . . . . . K
# 80
# . . . . . . r k
# . Q . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . b . . . P .
# . . q . R . . .
# . . . . . . . K
# 81
# . . . . . . r k
# . Q . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . b . . . P .
# . . . . R . . .
# . . . q . . . K
# 82
# . . . . . . r k
# . Q . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . b . . . P .
# . . . . R . . K
# . . . q . . . .
# 83
# . . . . . . r k
# . Q . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# . . . . R . . K
# . . . q b . . .
# 84
# . . Q . . . r k
# . . . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# . . . . R . . K
# . . . q b . . .
# 85
# . . Q . . . r k
# . . . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# . . . . R b . K
# . . . q . . . .
# 86
# . . Q . . . r k
# . . . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# R . . . . b . K
# . . . q . . . .
# 87
# . . Q . . . r k
# . . . . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# R . . q . b . K
# . . . . . . . .
# 88
# . . . . . . r k
# . . Q . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# R . . q . b . K
# . . . . . . . .
# 89
# . . . . . . r k
# . . Q . B . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# R q . . . b . K
# . . . . . . . .
# 90
# . . . . . B r k
# . . Q . . . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . . . . P .
# R q . . . b . K
# . . . . . . . .
# 91
# . . . . . B r k
# . . Q . . . . .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# q . . . . . P .
# R . . . . b . K
# . . . . . . . .
# 92
# . . . . . . r k
# . . Q . . . B .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# q . . . . . P .
# R . . . . b . K
# . . . . . . . .
# 93
# . . . . . . . k
# . . Q . . . r .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# q . . . . . P .
# R . . . . b . K
# . . . . . . . .
# 94
# . . . . . . . k
# . . . . . . r .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# q . Q . . . P .
# R . . . . b . K
# . . . . . . . .
# 95
# . . . . . . . k
# . . . . . . r .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . Q . . . P .
# q . . . . b . K
# . . . . . . . .
# 96
# . . . . . . . k
# . . . . . . r .
# p . . . . . p p
# P . . . . p . .
# . P . . . . . P
# . . . Q . . P .
# q . . . . b . K
# . . . . . . . .
# 97
# . . . . . . . k
# . . . . . . r .
# p . . . . . . p
# P . . . . p p .
# . P . . . . . P
# . . . Q . . P .
# q . . . . b . K
# . . . . . . . .
# 98
# . . . . . . . k
# . . . . . . r .
# p . . . . . . p
# P . . . . p P .
# . P . . . . . .
# . . . Q . . P .
# q . . . . b . K
# . . . . . . . .
# 99
# . . . . . . r k
# . . . . . . . .
# p . . . . . . p
# P . . . . p P .
# . P . . . . . .
# . . . Q . . P .
# q . . . . b . K
# . . . . . . . .
# 100
# . . . . . . r k
# . . . Q . . . .
# p . . . . . . p
# P . . . . p P .
# . P . . . . . .
# . . . . . . P .
# q . . . . b . K
# . . . . . . . .
# 101
# . . . . . . r k
# . . . Q . . . .
# p . . . . . . .
# P . . . . p p .
# . P . . . . . .
# . . . . . . P .
# q . . . . b . K
# . . . . . . . .
# 102
# . . . . Q . r k
# . . . . . . . .
# p . . . . . . .
# P . . . . p p .
# . P . . . . . .
# . . . . . . P .
# q . . . . b . K
# . . . . . . . .
# 103
# . . . . Q . r .
# . . . . . . k .
# p . . . . . . .
# P . . . . p p .
# . P . . . . . .
# . . . . . . P .
# q . . . . b . K
# . . . . . . . .
# 104
# . . . . . . Q .
# . . . . . . k .
# p . . . . . . .
# P . . . . p p .
# . P . . . . . .
# . . . . . . P .
# q . . . . b . K
# . . . . . . . .
# 105
# . . . . . . Q .
# . . . . . . . .
# p . . . . k . .
# P . . . . p p .
# . P . . . . . .
# . . . . . . P .
# q . . . . b . K
# . . . . . . . .
# 106
# . . . . . . Q .
# . . . . . . . .
# p . . . . k . .
# P . . . . p p .
# . P . . . . . .
# . . . . . . P K
# q . . . . b . .
# . . . . . . . .
# 107
# . . . . . . Q .
# . . . . . . . .
# p . . . . k . .
# P . . . . p p .
# . P . . . . . .
# . . . . b . P K
# q . . . . . . .
# . . . . . . . .
# 108
# . . . . . . . Q
# . . . . . . . .
# p . . . . k . .
# P . . . . p p .
# . P . . . . . .
# . . . . b . P K
# q . . . . . . .
# . . . . . . . .
# 109
# . . . . . . . Q
# . . . . . . . .
# p . . . k . . .
# P . . . . p p .
# . P . . . . . .
# . . . . b . P K
# q . . . . . . .
# . . . . . . . .
# 110
# . . . . . . . Q
# . . . . . . . .
# p . . . k . . .
# P P . . . p p .
# . . . . . . . .
# . . . . b . P K
# q . . . . . . .
# . . . . . . . .
# 111
# . . . . . . . Q
# . . . . . . . .
# . . . . k . . .
# P p . . . p p .
# . . . . . . . .
# . . . . b . P K
# q . . . . . . .
# . . . . . . . .
# 112
# . . . . . . . Q
# . . . . . . . .
# P . . . k . . .
# . p . . . p p .
# . . . . . . . .
# . . . . b . P K
# q . . . . . . .
# . . . . . . . .
# 113
# . . . . . . . Q
# . . . . . . . .
# P . . . k . . .
# . p b . . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 114
# . . . Q . . . .
# . . . . . . . .
# P . . . k . . .
# . p b . . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 115
# . . . Q . b . .
# . . . . . . . .
# P . . . k . . .
# . p . . . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 116
# . . . . Q b . .
# . . . . . . . .
# P . . . k . . .
# . p . . . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 117
# . . . . Q b . .
# . . . . . . . .
# P . . . . k . .
# . p . . . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 118
# . . . . Q b . .
# P . . . . . . .
# . . . . . k . .
# . p . . . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 119
# . . . . Q b . .
# P . . . . . k .
# . . . . . . . .
# . p . . . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 120
# . . . . . b . .
# P . . . . . k .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 121
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 122
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 123
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 124
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 125
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 126
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 127
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 128
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 129
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 130
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 131
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 132
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 133
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 134
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 135
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . Q . p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 136
# . . . . . b . k
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 137
# . . . . . b k .
# P . . . . . . .
# . . . . . . . .
# . p . . Q p p .
# . . . . . . . .
# . . . . . . P K
# q . . . . . . .
# . . . . . . . .
# 138

# %%
# create a game object
game = chess.pgn.Game()
game.headers["Event"] = "AI Self Play"
game.headers["White"] = "Your Model"
game.headers["Black"] = "Your Model"
game.headers["Result"] = board.result()

# add moves to the game node
node = game
for move in board.move_stack:
    node = node.add_variation(move)

# save to PGN file
with open("output_game1.pgn", "w", encoding="utf-8") as pgn_file:
    print(game, file=pgn_file)
