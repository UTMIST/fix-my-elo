# %%
from agent import Agent
from model_files.SLPolicyValueGPU import SLPolicyValueNetwork
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SLPolicyValueNetwork().to(device)
model.load_state_dict(torch.load("model_files/V3SL_trained.pth", map_location=torch.device("cuda"))["model"])

agent = Agent(policy_value_network=model, c_puct=0.5, dirichlet_alpha=0.3, dirichlet_epsilon=0)
agent.agent_vs_stockfish(2, 1000, "demo.pgn")
