# %%
from agent import Agent
from model_files.SLPolicyValueGPU import SLPolicyValueNetwork
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = SLPolicyValueNetwork().to(device)
model.load_state_dict(torch.load("model_files/sl_policy_value_network4.pth", map_location=torch.device("cuda")))

agent = Agent(policy_value_network=model, c_puct=1.0)
agent.training_self_play(num_training_iterations=1, num_games=1, train_to_test_ratio=0.8, num_simulations=5, num_testing_games=10, improvement_threshold=3)
# Out:
# self-play game: 1
# move: 1, e2e4 | board: rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1
# move: 2, d7d5 | board: rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1
# move: 3, d2d4 | board: rnbqkbnr/ppp1pppp/8/3p4/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2
# move: 4, g8h6 | board: rnbqkbnr/ppp1pppp/8/3p4/3PP3/8/PPP2PPP/RNBQKBNR b KQkq - 0 2
# move: 5, g1h3 | board: rnbqkb1r/ppp1pppp/7n/3p4/3PP3/8/PPP2PPP/RNBQKBNR w KQkq - 1 3
# move: 6, h8g8 | board: rnbqkb1r/ppp1pppp/7n/3p4/3PP3/7N/PPP2PPP/RNBQKB1R b KQkq - 2 3
# move: 7, b1d2 | board: rnbqkbr1/ppp1pppp/7n/3p4/3PP3/7N/PPP2PPP/RNBQKB1R w KQq - 3 4
# move: 8, c7c5 | board: rnbqkbr1/ppp1pppp/7n/3p4/3PP3/7N/PPPN1PPP/R1BQKB1R b KQq - 4 4
# move: 9, f1e2 | board: rnbqkbr1/pp2pppp/7n/2pp4/3PP3/7N/PPPN1PPP/R1BQKB1R w KQq - 0 5
# move: 10, e7e6 | board: rnbqkbr1/pp2pppp/7n/2pp4/3PP3/7N/PPPNBPPP/R1BQK2R b KQq - 1 5
# move: 11, e1g1 | board: rnbqkbr1/pp3ppp/4p2n/2pp4/3PP3/7N/PPPNBPPP/R1BQK2R w KQq - 0 6
# ...

# %%
torch.save(agent.policy_value_network.state_dict(), "sl_policy_value_network_from_mcts_self_play.pth")
